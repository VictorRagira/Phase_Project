# %% [markdown]
# Data cleaning & Analysis in Pandas

# %% [markdown]
# 1. Business understanding and Defining Business Question

# %% [raw]
# a). Business Understanding:
#
# Introduction:
# The real-world problem this project aims to solve is Microsoft's entry into the movie industry. Microsoft intends to establish a new movie studio but lacks knowledge and insights into the types of films that perform well in terms of box office revenue and audience reception. The objective is to explore the movie data to provide actionable insights that can guide Microsoft in deciding what type of films to create.
#
# Specifying the Data Analytic Question
#
# - To create insight on the types of films that perform well in terms of numvotes
# - To create insight on audience reception on different types of movies
# - To provide any other actionable insights to guide Microsoft on which films to create
#
# b). Understanding the data
#
# Data Sources: The dataset includes movie data from multiple sources, such as Box Office Moj and IMDB. These sources provide comprehensive information about movies, including box office performance, ratings, and other relevant details. There are other data sources which we haven't used, but we'd like to include on this list as well. There is data set from Rotten Tomatoes, TheMovieDB, and The Numbers
#
# Data Suitability:
# •	Box Office Mojo provides box office revenue data, which is essential for understanding a movie's financial success.
# •	IMDB and Rotten Tomatoes offer information about user and critic ratings, helping gauge audience and critical reception.
# •	TheMovieDB provides additional movie details, including cast and crew information.
# •	The Numbers offer comprehensive data on budgets, production costs, and revenue.
#
# Conclusion: The project's implications for the real-world problem are significant. It will enable Microsoft's new movie studio to make data-driven decisions, potentially increasing the studio's chances of success. Additionally, it can lead to the creation of movies that better cater to audience preferences, enhancing the overall movie-watching experience.
#
# c). Recording the Experimental Design
#
# 1. Business understanding and Defining Business Question
# 2. Reading the data
# 3. Checking the data
# 4. Data cleaning
# 5. Exploratory data analysis(Univeriate, Bivariate and Multivariate)
# 6. Conclusion
# 7. Recommendation

# %% [markdown]
# 2.0 Reading the Data

# %%
# Import libraries 

import sqlite3
import pandas as pd

# %% [markdown]
# 2.1 Loading the Dataset

# %%
# Import dataset 1
# Connect to the SQLite database 

conn = sqlite3.connect('im.db')

# Create a cursor object to interact with the database
cursor = conn.cursor()

# %%
cursor.execute("""SELECT * FROM movie_basics;""").fetchall()
# Out:
# [('tt0063540', 'Sunghursh', 'Sunghursh', 2013, 175.0, 'Action,Crime,Drama'),
#  ('tt0066787',
#   'One Day Before the Rainy Season',
#   'Ashad Ka Ek Din',
#   2019,
#   114.0,
#   'Biography,Drama'),
#  ('tt0069049',
#   'The Other Side of the Wind',
#   'The Other Side of the Wind',
#   2018,
#   122.0,
#   'Drama'),
#  ('tt0069204',
#   'Sabse Bada Sukh',
#   'Sabse Bada Sukh',
#   2018,
#   None,
#   'Comedy,Drama'),
#  ('tt0100275',
#   'The Wandering Soap Opera',
#   'La Telenovela Errante',
#   2017,
#   80.0,
#   'Comedy,Drama,Fantasy'),
#  ('tt0111414', 'A Thin Life', 'A Thin Life', 2018, 75.0, 'Comedy'),
#  ('tt0112502', 'Bigfoot', 'Bigfoot', 2017, None, 'Horror,Thriller'),
#  ('tt0137204',
#   'Joe Finds Grace',
#   'Joe Finds Grace',
#   2017,
#   83.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0139613', 'O Silêncio', 'O Silêncio', 2012, None, 'Documentary,History'),
#  ('tt0144449',
#   'Nema aviona za Zagreb',
#   'Nema aviona za Zagreb',
#   2012,
#   82.0,
#   'Biography'),
#  ('tt0146592', 'Pál Adrienn', 'Pál Adrienn', 2010, 136.0, 'Drama'),
#  ('tt0154039',
#   'So Much for Justice!',
#   'Oda az igazság',
#   2010,
#   100.0,
#   'History'),
#  ('tt0159369',
#   'Cooper and Hemingway: The True Gen',
#   'Cooper and Hemingway: The True Gen',
#   2013,
#   180.0,
#   'Documentary'),
#  ('tt0162942',
#   'Children of the Green Dragon',
#   'A zöld sárkány gyermekei',
#   2010,
#   89.0,
#   'Drama'),
#  ('tt0170651',
#   'T.G.M. - osvoboditel',
#   'T.G.M. - osvoboditel',
#   2018,
#   60.0,
#   'Documentary'),
#  ('tt0176694',
#   'The Tragedy of Man',
#   'Az ember tragédiája',
#   2011,
#   160.0,
#   'Animation,Drama,History'),
#  ('tt0187902',
#   "How Huang Fei-hong Rescued the Orphan from the Tiger's Den",
#   "How Huang Fei-hong Rescued the Orphan from the Tiger's Den",
#   2011,
#   None,
#   None),
#  ('tt0192528', 'Heaven & Hell', 'Reverse Heaven', 2018, 104.0, 'Drama'),
#  ('tt0230212', 'The Final Journey', 'The Final Journey', 2010, 120.0, 'Drama'),
#  ('tt0247643',
#   'Los pájaros se van con la muerte',
#   'Los pájaros se van con la muerte',
#   2011,
#   110.0,
#   'Drama,Mystery'),
#  ('tt0249516',
#   'Foodfight!',
#   'Foodfight!',
#   2012,
#   91.0,
#   'Action,Animation,Comedy'),
#  ('tt0250404', 'Godfather', 'Godfather', 2012, None, 'Crime,Drama'),
#  ('tt0253093', 'Gangavataran', 'Gangavataran', 2018, 134.0, None),
#  ('tt0255820',
#   'Return to Babylon',
#   'Return to Babylon',
#   2013,
#   75.0,
#   'Biography,Comedy,Drama'),
#  ('tt0262218',
#   'Akakis mogzauroba',
#   'Akakis mogzauroba',
#   2012,
#   44.0,
#   'Documentary'),
#  ('tt0262759',
#   'Seven Jews from My Class',
#   'Siedmiu Zydów z mojej klasy',
#   2018,
#   40.0,
#   'Documentary'),
#  ('tt0263814', 'On kadin', 'On kadin', 2019, None, 'Drama'),
#  ('tt0276568',
#   'To Chase a Million',
#   'To Chase a Million',
#   2018,
#   97.0,
#   'Action,Drama'),
#  ('tt0277964',
#   'Prague: The Restless Heart of Europe',
#   'Praha - neklidné srdce Evropy',
#   2018,
#   59.0,
#   'Documentary,History'),
#  ('tt0283440', 'Short Time Heroes', 'Kurzzeithelden', 2015, 45.0, 'Sci-Fi'),
#  ('tt0285252', "Life's a Beach", "Life's a Beach", 2012, 100.0, 'Comedy'),
#  ('tt0285423', 'Abolição', 'Abolição', 2019, None, 'Documentary'),
#  ('tt0293069', 'Dark Blood', 'Dark Blood', 2012, 86.0, 'Thriller'),
#  ('tt0293429',
#   'Mortal Kombat',
#   'Mortal Kombat',
#   2021,
#   None,
#   'Action,Adventure,Fantasy'),
#  ('tt0297400', 'Snowblind', 'Snowblind', 2015, None, 'Crime,Drama'),
#  ('tt0306058', 'Second Coming', 'Second Coming', 2012, 95.0, None),
#  ('tt0311448',
#   'Lives No Longer Ours',
#   'Lives No Longer Ours',
#   2011,
#   90.0,
#   'Drama,Romance'),
#  ('tt0312305',
#   'Quantum Quest: A Cassini Space Odyssey',
#   'Quantum Quest: A Cassini Space Odyssey',
#   2010,
#   45.0,
#   'Adventure,Animation,Sci-Fi'),
#  ('tt0315642', 'Wazir', 'Wazir', 2016, 103.0, 'Action,Crime,Drama'),
#  ('tt0323808',
#   'The Wicker Tree',
#   'The Wicker Tree',
#   2011,
#   96.0,
#   'Drama,Horror'),
#  ('tt0326592', 'The Overnight', 'The Overnight', 2010, 88.0, None),
#  ('tt0326965',
#   'In My Sleep',
#   'In My Sleep',
#   2010,
#   104.0,
#   'Drama,Mystery,Thriller'),
#  ('tt0328810', 'My Land', 'Aamaar Bhuvan', 2018, 102.0, 'Drama,Family'),
#  ('tt0329539',
#   'Rice Girl',
#   'Rice Girl',
#   2014,
#   95.0,
#   'Adventure,Comedy,Romance'),
#  ('tt0330811', 'Regret Not Speaking', 'Regret Not Speaking', 2011, None, None),
#  ('tt0330987',
#   'Tiden är en dröm, del 2',
#   'Tiden är en dröm, del 2',
#   2014,
#   109.0,
#   None),
#  ('tt0331312',
#   'This Wretched Life',
#   'This Wretched Life',
#   2010,
#   99.0,
#   'Comedy,Drama'),
#  ('tt0331314',
#   'Bunyan and Babe',
#   'Bunyan and Babe',
#   2017,
#   84.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0337692',
#   'On the Road',
#   'On the Road',
#   2012,
#   124.0,
#   'Adventure,Drama,Romance'),
#  ('tt0337882', 'Blind Sided', 'Blind Sided', 2010, None, 'Comedy,Crime,Drama'),
#  ('tt0337926',
#   'Chatô - The King of Brazil',
#   'Chatô: O Rei do Brasil',
#   2015,
#   102.0,
#   'Biography'),
#  ('tt0339736', 'The Evil Within', 'The Evil Within', 2017, 98.0, 'Horror'),
#  ('tt0346045', 'Transeúntes', 'Transeúntes', 2015, 101.0, 'Comedy,Drama'),
#  ('tt0357717', 'Haar Jeet', 'Haar Jeet', 2018, None, 'Drama'),
#  ('tt0359950',
#   'The Secret Life of Walter Mitty',
#   'The Secret Life of Walter Mitty',
#   2013,
#   114.0,
#   'Adventure,Comedy,Drama'),
#  ('tt0360556',
#   'Fahrenheit 451',
#   'Fahrenheit 451',
#   2018,
#   100.0,
#   'Drama,Sci-Fi,Thriller'),
#  ('tt0364201',
#   'Aman Ke Farishtey',
#   'Aman Ke Farishtey',
#   2016,
#   137.0,
#   'Action'),
#  ('tt0365545',
#   'Nappily Ever After',
#   'Nappily Ever After',
#   2018,
#   98.0,
#   'Comedy,Drama,Romance'),
#  ('tt0365907',
#   'A Walk Among the Tombstones',
#   'A Walk Among the Tombstones',
#   2014,
#   114.0,
#   'Action,Crime,Drama'),
#  ('tt0368133',
#   'The Promise of Perfume',
#   'The Promise of Perfume',
#   2017,
#   57.0,
#   'Documentary'),
#  ('tt0369610',
#   'Jurassic World',
#   'Jurassic World',
#   2015,
#   124.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0372538', 'Spy', 'Spy', 2011, 110.0, 'Action,Crime,Drama'),
#  ('tt0376136', 'The Rum Diary', 'The Rum Diary', 2011, 119.0, 'Comedy,Drama'),
#  ('tt0376479',
#   'American Pastoral',
#   'American Pastoral',
#   2016,
#   108.0,
#   'Crime,Drama'),
#  ('tt0377981',
#   'Gnomeo & Juliet',
#   'Gnomeo & Juliet',
#   2011,
#   84.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0378546',
#   'The Payback Man',
#   'The Payback Man',
#   2010,
#   None,
#   'Crime,Drama,Thriller'),
#  ('tt0381957', 'Cloud Cuckoo Land', 'Cloud Cuckoo Land', 2012, 92.0, 'Drama'),
#  ('tt0383010',
#   'The Three Stooges',
#   'The Three Stooges',
#   2012,
#   92.0,
#   'Comedy,Family'),
#  ('tt0385887',
#   'Motherless Brooklyn',
#   'Motherless Brooklyn',
#   2019,
#   None,
#   'Crime,Drama'),
#  ('tt0393049',
#   "Anderson's Cross",
#   "Anderson's Cross",
#   2010,
#   98.0,
#   'Comedy,Drama,Romance'),
#  ('tt0396123', 'Den milde smerte', 'Den milde smerte', 2010, 280.0, 'Drama'),
#  ('tt0398286',
#   'Tangled',
#   'Tangled',
#   2010,
#   100.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0400320',
#   'The Connecticut Kid',
#   'The Connecticut Kid',
#   2011,
#   87.0,
#   'Adventure'),
#  ('tt0401729',
#   'John Carter',
#   'John Carter',
#   2012,
#   132.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0402887', 'Capture the Flag', 'Capture the Flag', 2010, None, 'Drama'),
#  ('tt0403645',
#   'Burnt by the Sun 2',
#   'Utomlennye solntsem 2',
#   2010,
#   181.0,
#   'Drama,History,War'),
#  ('tt0403935',
#   'Action Jackson',
#   'Action Jackson',
#   2014,
#   144.0,
#   'Action,Thriller'),
#  ('tt0404978', 'Gambit', 'Gambit', 2012, 89.0, 'Comedy,Crime'),
#  ('tt0406282', 'Bubbles', 'Bubbles', 2011, 80.0, 'Drama'),
#  ('tt0407194',
#   'Seven Fallen Objects',
#   'Seven Fallen Objects',
#   2011,
#   90.0,
#   'Comedy,Drama'),
#  ('tt0409379', 'In Secret', 'In Secret', 2013, 107.0, 'Crime,Drama,Thriller'),
#  ('tt0409847',
#   'Cowboys & Aliens',
#   'Cowboys & Aliens',
#   2011,
#   119.0,
#   'Action,Sci-Fi,Thriller'),
#  ('tt0411951', 'Tekken', 'Tekken', 2010, 87.0, 'Action,Crime,Drama'),
#  ('tt0417610', 'Asleep in the Sun', 'Dormir al sol', 2010, 83.0, 'Fantasy'),
#  ('tt0417750',
#   'Hempsters: Plant the Seed',
#   'Hempsters: Plant the Seed',
#   2010,
#   90.0,
#   'Documentary'),
#  ('tt0419692',
#   'Disconnect',
#   'Disconnect',
#   2010,
#   112.0,
#   'Drama,Mystery,Sci-Fi'),
#  ('tt0420293',
#   'The Stanford Prison Experiment',
#   'The Stanford Prison Experiment',
#   2015,
#   122.0,
#   'Biography,Drama,History'),
#  ('tt0423474',
#   'Venus & Vegas',
#   'Venus & Vegas',
#   2010,
#   95.0,
#   'Action,Comedy,Crime'),
#  ('tt0424859', 'The Ninth Cloud', 'The Ninth Cloud', 2014, 93.0, 'Drama'),
#  ('tt0425785',
#   'El borde del tiempo',
#   'El borde del tiempo',
#   2011,
#   100.0,
#   'Drama'),
#  ('tt0426410', 'Beisbol', 'Beisbol', 2010, None, 'Documentary'),
#  ('tt0426566', 'Pots and Pans', 'Acorralados', 2012, None, 'Drama'),
#  ('tt0427152',
#   'Dinner for Schmucks',
#   'Dinner for Schmucks',
#   2010,
#   114.0,
#   'Comedy'),
#  ('tt0427340',
#   'Masters of the Universe',
#   'Masters of the Universe',
#   2021,
#   None,
#   'Action,Adventure,Drama'),
#  ('tt0427543',
#   'A Million Little Pieces',
#   'A Million Little Pieces',
#   2018,
#   113.0,
#   'Drama'),
#  ('tt0429493',
#   'The A-Team',
#   'The A-Team',
#   2010,
#   117.0,
#   'Action,Adventure,Thriller'),
#  ('tt0430524', 'The Rescuer', 'The Rescuer', 2011, 84.0, 'Documentary'),
#  ('tt0431021',
#   'The Possession',
#   'The Possession',
#   2012,
#   92.0,
#   'Horror,Mystery,Thriller'),
#  ('tt0432010',
#   'The Queen of Sheba Meets the Atom Man',
#   'The Queen of Sheba Meets the Atom Man',
#   2018,
#   110.0,
#   'Comedy'),
#  ('tt0433035', 'Real Steel', 'Real Steel', 2011, 127.0, 'Action,Drama,Family'),
#  ('tt0433397', 'Satin', 'Satin', 2011, 84.0, 'Comedy,Drama,Music'),
#  ('tt0433533',
#   'Caleuche: El llamado del Mar',
#   'Caleuche: El llamado del Mar',
#   2012,
#   100.0,
#   'Drama,Fantasy,Horror'),
#  ('tt0433787',
#   "L'apocalisse delle scimmie",
#   "L'apocalisse delle scimmie",
#   2012,
#   None,
#   'Drama'),
#  ('tt0435651', 'The Giver', 'The Giver', 2014, 97.0, 'Drama,Romance,Sci-Fi'),
#  ('tt0435761',
#   'Toy Story 3',
#   'Toy Story 3',
#   2010,
#   103.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0436230',
#   'Mexican Devil',
#   'The Devil Inside',
#   2010,
#   None,
#   'Horror,Thriller'),
#  ('tt0436782',
#   'A Life in the Death of Joe Meek',
#   'A Life in the Death of Joe Meek',
#   2013,
#   122.0,
#   'Documentary'),
#  ('tt0437086',
#   'Alita: Battle Angel',
#   'Alita: Battle Angel',
#   2019,
#   122.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0437462',
#   'Cargo, les hommes perdus.',
#   'Cargo, les hommes perdus.',
#   2010,
#   93.0,
#   'Adventure,Romance'),
#  ('tt0438973', 'Sealand', 'Sealand', 2019, None, 'Biography,Drama'),
#  ('tt0439724', 'Moving Target', 'Moving Target', 2011, None, 'Drama,Thriller'),
#  ('tt0439801',
#   'Segurança Nacional',
#   'Segurança Nacional',
#   2010,
#   86.0,
#   'Action'),
#  ('tt0441506',
#   'Stolen Memories',
#   'Stolen Memories',
#   2012,
#   None,
#   'Documentary'),
#  ('tt0441779',
#   'My Nappy Roots: A Journey Through Black Hair-itage',
#   'My Nappy Roots: A Journey Through Black Hair-itage',
#   2010,
#   90.0,
#   'Documentary'),
#  ('tt0441881',
#   'Danger Close: The Battle of Long Tan',
#   'Danger Close: The Battle of Long Tan',
#   2019,
#   None,
#   'Action,Drama,War'),
#  ('tt0443272', 'Lincoln', 'Lincoln', 2012, 150.0, 'Biography,Drama,History'),
#  ('tt0443331',
#   'Milenge Milenge',
#   'Milenge Milenge',
#   2010,
#   109.0,
#   'Drama,Romance'),
#  ('tt0443465',
#   'Before We Go',
#   'Before We Go',
#   2014,
#   95.0,
#   'Comedy,Drama,Romance'),
#  ('tt0443533',
#   'The History of Love',
#   'The History of Love',
#   2016,
#   134.0,
#   'Drama,Romance,War'),
#  ('tt0444531', 'Vidas pequeñas', 'Vidas pequeñas', 2010, 115.0, 'Drama'),
#  ('tt0445054',
#   '7 Days',
#   'Les 7 jours du talion',
#   2010,
#   105.0,
#   'Crime,Drama,Horror'),
#  ('tt0446029',
#   'Scott Pilgrim vs. the World',
#   'Scott Pilgrim vs. the World',
#   2010,
#   112.0,
#   'Action,Comedy,Fantasy'),
#  ('tt0446686', 'Dream Street', 'Dream Street', 2010, None, 'Drama'),
#  ('tt0446792',
#   'Surviving in L.A.',
#   'Surviving in L.A.',
#   2019,
#   None,
#   'Comedy,Drama,Romance'),
#  ('tt0448022',
#   'A Bird of the Air',
#   'A Bird of the Air',
#   2011,
#   108.0,
#   'Drama,Romance'),
#  ('tt0448115', 'Shazam!', 'Shazam!', 2019, 132.0, 'Action,Adventure,Comedy'),
#  ('tt0448694',
#   'Puss in Boots',
#   'Puss in Boots',
#   2011,
#   90.0,
#   'Action,Adventure,Animation'),
#  ('tt0449005',
#   'Diary of a Bad Lad',
#   'Diary of a Bad Lad',
#   2010,
#   92.0,
#   'Comedy,Crime'),
#  ('tt0451108', 'Mad World', 'Mad World', 2010, 98.0, 'Drama'),
#  ('tt0451154', 'The Passing', 'The Passing', 2011, 92.0, 'Horror'),
#  ('tt0451201', 'Clawed', 'Sludge', 2017, 95.0, 'Horror'),
#  ('tt0451279',
#   'Wonder Woman',
#   'Wonder Woman',
#   2017,
#   141.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0452183', 'Blunt Movie', 'Blunt Movie', 2013, 83.0, 'Comedy,Romance'),
#  ('tt0452664', 'Party Crashers', 'Os Penetras', 2012, 88.0, 'Comedy'),
#  ('tt0453562', '42', '42', 2013, 128.0, 'Biography,Drama,Sport'),
#  ('tt0454155',
#   'El hada buena - Una fábula peronista',
#   'El hada buena - Una fábula peronista',
#   2010,
#   85.0,
#   'Comedy,Drama,Sci-Fi'),
#  ('tt0454876',
#   'Life of Pi',
#   'Life of Pi',
#   2012,
#   127.0,
#   'Adventure,Drama,Fantasy'),
#  ('tt0455323', 'Being Flynn', 'Being Flynn', 2012, 102.0, 'Drama'),
#  ('tt0455407', 'The Crazies', 'The Crazies', 2010, 101.0, 'Horror,Thriller'),
#  ('tt0455944',
#   'The Equalizer',
#   'The Equalizer',
#   2014,
#   132.0,
#   'Action,Crime,Thriller'),
#  ('tt0457591',
#   'Memorias del desarrollo',
#   'Memorias del desarrollo',
#   2010,
#   113.0,
#   'Drama'),
#  ('tt0458339',
#   'Captain America: The First Avenger',
#   'Captain America: The First Avenger',
#   2011,
#   124.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0458413',
#   'A Long Way Down',
#   'A Long Way Down',
#   2014,
#   96.0,
#   'Comedy,Drama'),
#  ('tt0458481',
#   'Sin City: A Dame to Kill For',
#   'Sin City: A Dame to Kill For',
#   2014,
#   102.0,
#   'Crime,Thriller'),
#  ('tt0459748',
#   'Generation P',
#   'Generation P',
#   2011,
#   112.0,
#   'Comedy,Drama,Sci-Fi'),
#  ('tt0460528',
#   'One Step Beyond: The True Story of Géraldine Fasnacht',
#   'One Step Beyond',
#   2012,
#   56.0,
#   'Documentary'),
#  ('tt0460778', 'Drunkboat', 'Drunkboat', 2010, 98.0, 'Drama'),
#  ('tt0460809', 'The Grasslands', 'The Grasslands', 2011, 114.0, 'Drama'),
#  ('tt0460890',
#   'The Only Living Boy in New York',
#   'The Only Living Boy in New York',
#   2017,
#   89.0,
#   'Drama'),
#  ('tt0460957', "Texxas Jam '78", "Texxas Jam '78", 2012, 60.0, 'Documentary'),
#  ('tt0461336',
#   'Saving Private Perez',
#   'Salvando al Soldado Pérez',
#   2011,
#   105.0,
#   'Adventure,Comedy,Western'),
#  ('tt0462036',
#   'Steve Phoenix: The Untold Story',
#   'Steve Phoenix: The Untold Story',
#   2012,
#   110.0,
#   'Drama'),
#  ('tt0462335', 'High-Rise', 'High-Rise', 2015, 119.0, 'Drama,Horror,Sci-Fi'),
#  ('tt0462516', 'Satan Hates You', 'Satan Hates You', 2010, 94.0, 'Horror'),
#  ('tt0462536',
#   'Silent Alarm',
#   'Silent Alarm',
#   2011,
#   82.0,
#   'Comedy,Drama,Thriller'),
#  ('tt0463311', 'Federal', 'Federal', 2010, 91.0, 'Drama,Thriller'),
#  ('tt0463960',
#   'The Devil You Know',
#   'The Devil You Know',
#   2013,
#   76.0,
#   'Mystery,Thriller'),
#  ('tt0464032',
#   'Guns, Drugs and Dirty Money',
#   'Guns, Drugs and Dirty Money',
#   2010,
#   123.0,
#   'Action,Comedy,Crime'),
#  ('tt0464054',
#   'House at the End of the Drive',
#   'House at the End of the Drive',
#   2014,
#   91.0,
#   'Horror,Thriller'),
#  ('tt0464154', 'Piranha 3D', 'Piranha 3D', 2010, 88.0, 'Comedy,Horror'),
#  ('tt0464162',
#   'Komaram Puli',
#   'Komaram Puli',
#   2010,
#   163.0,
#   'Action,Crime,Thriller'),
#  ('tt0464891', 'Act Your Age', 'Act Your Age', 2011, 101.0, 'Comedy,Drama'),
#  ('tt0465637', 'Taken by Force', 'Taken by Force', 2010, 90.0, 'Action,Drama'),
#  ('tt0465760', 'Sensual', 'Sensual', 2010, 99.0, 'Drama'),
#  ('tt0466553',
#   'Golapi Ekhon Bilatey',
#   'Golapi Ekhon Bilatey',
#   2010,
#   None,
#   'Musical'),
#  ('tt0466893', 'Margaret', 'Margaret', 2011, 150.0, 'Drama'),
#  ('tt0469021',
#   'Alan Partridge',
#   'Alan Partridge: Alpha Papa',
#   2013,
#   90.0,
#   'Action,Comedy,Crime'),
#  ('tt0469094', 'Harlem Hostel', 'Harlem Hostel', 2010, 81.0, 'Comedy,Drama'),
#  ('tt0469152', 'Smoking/Non-Smoking', 'The Pack', 2011, 84.0, 'Drama'),
#  ('tt0469158',
#   'Platinum Illusions',
#   'Platinum Illusions',
#   2011,
#   None,
#   'Action,Drama'),
#  ('tt0470752',
#   'Ex Machina',
#   'Ex Machina',
#   2014,
#   108.0,
#   'Drama,Mystery,Sci-Fi'),
#  ('tt0470936',
#   'Hot Country, Cold Winter',
#   'Tak erkir, tsurt dzmer',
#   2016,
#   104.0,
#   'Drama'),
#  ('tt0471042',
#   'Tower Heist',
#   'Tower Heist',
#   2011,
#   104.0,
#   'Action,Comedy,Crime'),
#  ('tt0472181',
#   'The Smurfs',
#   'The Smurfs',
#   2011,
#   103.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0472399',
#   'The Mechanic',
#   'The Mechanic',
#   2011,
#   93.0,
#   'Action,Crime,Thriller'),
#  ('tt0473032',
#   'Escape from Heaven',
#   'Escape from Heaven',
#   2018,
#   None,
#   'Comedy,Fantasy'),
#  ('tt0473075',
#   'Prince of Persia: The Sands of Time',
#   'Prince of Persia: The Sands of Time',
#   2010,
#   116.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0473088', 'Stan', 'Stan', 2011, None, 'Comedy'),
#  ('tt0473122', 'Bamboo Shark', 'Bamboo Shark', 2011, None, 'Comedy'),
#  ('tt0473343', 'Cielito lindo', 'Cielito lindo', 2010, 91.0, 'Drama,Thriller'),
#  ('tt0475239', 'Clutch', 'Clutch', 2012, None, 'Action,Drama'),
#  ('tt0475290',
#   'Hail, Caesar!',
#   'Hail, Caesar!',
#   2016,
#   106.0,
#   'Comedy,Drama,Music'),
#  ('tt0475360', 'Persona Au Gratin', 'Persona Au Gratin', 2012, 93.0, 'Comedy'),
#  ('tt0475983',
#   'The Deafening Silence of a Very Bright Light',
#   'The Deafening Silence of a Very Bright Light',
#   2010,
#   92.0,
#   'Drama'),
#  ('tt0476023', 'Stiffs', 'Stiffs', 2010, 104.0, 'Comedy'),
#  ('tt0477080', 'Unstoppable', 'Unstoppable', 2010, 98.0, 'Action,Thriller'),
#  ('tt0477087',
#   'Sid Bernstein Presents...',
#   'Sid Bernstein Presents...',
#   2010,
#   100.0,
#   'Documentary'),
#  ('tt0477302',
#   'Extremely Loud & Incredibly Close',
#   'Extremely Loud & Incredibly Close',
#   2011,
#   129.0,
#   'Adventure,Drama,Mystery'),
#  ('tt0478304',
#   'The Tree of Life',
#   'The Tree of Life',
#   2011,
#   139.0,
#   'Drama,Fantasy'),
#  ('tt0478660',
#   'El horror de la dama del lago',
#   'El horror de la dama del lago',
#   2010,
#   90.0,
#   'Fantasy,Horror,Thriller'),
#  ('tt0478970', 'Ant-Man', 'Ant-Man', 2015, 117.0, 'Action,Adventure,Comedy'),
#  ('tt0479051',
#   'The Greater Meaning of Water',
#   'The Greater Meaning of Water',
#   2010,
#   60.0,
#   'Drama,Sport'),
#  ('tt0479204', 'Perfect Life', 'Perfect Life', 2010, 98.0, 'Horror,Thriller'),
#  ('tt0479807', 'Abhishapt', 'Abhishapt', 2011, None, 'Drama'),
#  ('tt0479997',
#   'Season of the Witch',
#   'Season of the Witch',
#   2011,
#   95.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0480239',
#   'Atlas Shrugged: Part I',
#   'Atlas Shrugged: Part I',
#   2011,
#   97.0,
#   'Drama,Mystery,Sci-Fi'),
#  ('tt0480255',
#   'The Losers',
#   'The Losers',
#   2010,
#   97.0,
#   'Action,Adventure,Crime'),
#  ('tt0480687', 'Hall Pass', 'Hall Pass', 2011, 105.0, 'Comedy,Romance'),
#  ('tt0481470',
#   'Felix Austria!',
#   'Felix Austria!',
#   2013,
#   77.0,
#   'Biography,Documentary,History'),
#  ('tt0481499',
#   'The Croods',
#   'The Croods',
#   2013,
#   98.0,
#   'Action,Adventure,Animation'),
#  ('tt0482459', 'Bandage', 'Bandeiji', 2010, 119.0, 'Drama,Music,Romance'),
#  ('tt0482461',
#   'Barry Munday',
#   'Barry Munday',
#   2010,
#   95.0,
#   'Comedy,Drama,Romance'),
#  ('tt0483586', 'Chasing 3000', 'Chasing 3000', 2010, 115.0, 'Family,Sport'),
#  ('tt0483740', 'Monkey Man', 'Monkey Man', 2011, None, 'Comedy'),
#  ('tt0483839',
#   'A Woman Is a Woman',
#   'A Woman Is a Woman',
#   2010,
#   102.0,
#   'Comedy,Drama'),
#  ('tt0484037',
#   'Gente mala del norte',
#   'Gente mala del norte',
#   2011,
#   97.0,
#   'Drama,History'),
#  ('tt0484828',
#   'La daga de Rasputín',
#   'La daga de Rasputín',
#   2011,
#   99.0,
#   'Adventure,Comedy'),
#  ('tt0485061',
#   'U Want Me 2 Kill Him?',
#   'uwantme2killhim?',
#   2013,
#   92.0,
#   'Drama,Thriller'),
#  ('tt0485521', 'Sushi in Suhl', 'Sushi in Suhl', 2012, 100.0, 'Comedy,Drama'),
#  ('tt0485985',
#   'Red Tails',
#   'Red Tails',
#   2012,
#   125.0,
#   'Action,Adventure,Drama'),
#  ('tt0486622', 'Making Change', 'Making Change', 2012, 94.0, 'Drama'),
#  ('tt0490075', 'Aftermath', 'Aftermath', 2013, 84.0, 'Crime,Thriller'),
#  ('tt0490199', 'PrimeMates', 'PrimeMates', 2010, 82.0, 'Comedy,Drama'),
#  ('tt0490215', 'Silence', 'Silence', 2016, 161.0, 'Adventure,Drama,History'),
#  ('tt0490236', 'The Invited', 'The Invited', 2010, 95.0, 'Horror,Thriller'),
#  ('tt0490847', 'Double Tap', 'Double Tap', 2011, 100.0, 'Action,Crime,Drama'),
#  ('tt0491152',
#   'Something Borrowed',
#   'Something Borrowed',
#   2011,
#   112.0,
#   'Comedy,Drama,Romance'),
#  ('tt0491175', 'Suburbicon', 'Suburbicon', 2017, 105.0, 'Comedy,Crime,Drama'),
#  ('tt0491203',
#   'Tulip Fever',
#   'Tulip Fever',
#   2017,
#   105.0,
#   'Drama,History,Romance'),
#  ('tt0492389',
#   'Furry Vengeance',
#   'Furry Vengeance',
#   2010,
#   92.0,
#   'Comedy,Family'),
#  ('tt0493076', 'Nina', 'Nina', 2016, 90.0, 'Biography,Drama,Music'),
#  ('tt0493405', 'CHIPS', 'CHIPS', 2017, 100.0, 'Action,Comedy,Crime'),
#  ('tt0493949',
#   'Ramona and Beezus',
#   'Ramona and Beezus',
#   2010,
#   103.0,
#   'Adventure,Comedy,Family'),
#  ('tt0494229', 'Good Sharma', 'Good Sharma', 2010, 100.0, 'Drama'),
#  ('tt0495024',
#   'Bad Blood',
#   'Bad Blood',
#   2012,
#   107.0,
#   'Horror,Mystery,Romance'),
#  ('tt0495037',
#   'O Inimigo Sem Rosto',
#   'O Inimigo Sem Rosto',
#   2010,
#   85.0,
#   'Crime,Drama'),
#  ('tt0496375',
#   'Prisoners of the Sun',
#   'Prisoners of the Sun',
#   2013,
#   85.0,
#   'Action,Adventure,Horror'),
#  ('tt0498351',
#   'The Hero of Color City',
#   'The Hero of Color City',
#   2014,
#   77.0,
#   'Animation,Family'),
#  ('tt0498381', 'Rings', 'Rings', 2017, 102.0, 'Drama,Horror,Mystery'),
#  ('tt0499097',
#   'Without Remorse',
#   'Without Remorse',
#   2020,
#   None,
#   'Action,Crime,Drama'),
#  ('tt0499608', 'Tranced', 'Tranced', 2010, None, 'Drama,Fantasy,Romance'),
#  ('tt0756727',
#   "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#   "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#   2010,
#   116.0,
#   'Biography,Documentary,Music'),
#  ('tt0758752',
#   'Love & Other Drugs',
#   'Love & Other Drugs',
#   2010,
#   112.0,
#   'Comedy,Drama,Romance'),
#  ('tt0762138', 'Syrup', 'Syrup', 2013, 90.0, 'Comedy,Drama,Romance'),
#  ('tt0763831',
#   'A Thousand Words',
#   'A Thousand Words',
#   2012,
#   91.0,
#   'Comedy,Drama'),
#  ('tt0765446',
#   'Escape from Planet Earth',
#   'Escape from Planet Earth',
#   2013,
#   89.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0765453', 'Have You Seen Me?', 'Have You Seen Me?', 2016, None, 'Comedy'),
#  ('tt0765465',
#   'The Legend of Secret Pass',
#   'The Legend of Secret Pass',
#   2019,
#   92.0,
#   'Animation,Family,Fantasy'),
#  ('tt0765485',
#   'Waste of Space',
#   'Waste of Space',
#   2010,
#   78.0,
#   'Adventure,Comedy,Sci-Fi'),
#  ('tt0768187',
#   'Me and My Umbrella',
#   'Eu e Meu Guarda-Chuva',
#   2010,
#   78.0,
#   'Family,Fantasy'),
#  ('tt0768222',
#   'Night of the Templar',
#   'Night of the Templar',
#   2013,
#   101.0,
#   'Horror,Mystery'),
#  ('tt0770703',
#   "What's Your Number?",
#   "What's Your Number?",
#   2011,
#   106.0,
#   'Comedy,Romance'),
#  ('tt0770728', 'California Indian', 'California Indian', 2011, 90.0, 'Drama'),
#  ('tt0770778',
#   'King of the Avenue',
#   'King of the Avenue',
#   2010,
#   83.0,
#   'Drama,Fantasy,Thriller'),
#  ('tt0770802', 'Samsara', 'Samsara', 2011, 102.0, 'Documentary,Music'),
#  ('tt0770819',
#   'Till You Get to Baraboo',
#   'Till You Get to Baraboo',
#   2011,
#   80.0,
#   'Comedy,Romance'),
#  ('tt0770828',
#   'Man of Steel',
#   'Man of Steel',
#   2013,
#   143.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0772175',
#   'Jersey Justice',
#   'Jersey Justice',
#   2014,
#   100.0,
#   'Action,Thriller'),
#  ('tt0772179', 'Kill', 'Kill', 2011, 90.0, 'Comedy,Horror,Thriller'),
#  ('tt0774519',
#   'The Chosen Heaven',
#   'El cielo elegido',
#   2010,
#   123.0,
#   'Drama,Thriller'),
#  ('tt0775440', 'Cell', 'Cell', 2016, 98.0, 'Action,Drama,Horror'),
#  ('tt0775461',
#   'The Rain Fairy',
#   'Destová víla',
#   2010,
#   100.0,
#   'Family,Fantasy'),
#  ('tt0775489',
#   'The Illusionist',
#   "L'illusionniste",
#   2010,
#   80.0,
#   'Animation,Drama'),
#  ('tt0775543',
#   'Night Catches Us',
#   'Night Catches Us',
#   2010,
#   90.0,
#   'Drama,Romance'),
#  ('tt0780504', 'Drive', 'Drive', 2011, 100.0, 'Crime,Drama'),
#  ('tt0780548',
#   'Kid Cannabis',
#   'Kid Cannabis',
#   2014,
#   110.0,
#   'Biography,Comedy,Crime'),
#  ('tt0780625', 'Santorini Blue', 'Santorini Blue', 2013, 90.0, 'Comedy,Drama'),
#  ('tt0780645',
#   'War of the Dead',
#   'War of the Dead',
#   2011,
#   86.0,
#   'Action,Adventure,Horror'),
#  ('tt0780653',
#   'The Wolfman',
#   'The Wolfman',
#   2010,
#   103.0,
#   'Drama,Fantasy,Horror'),
#  ('tt0781441', 'Escalade', 'Escalade', 2011, 80.0, 'Thriller'),
#  ('tt0782047', 'Irreversi', 'Irreversi', 2010, None, 'Thriller'),
#  ('tt0783640',
#   'The Last Full Measure',
#   'The Last Full Measure',
#   2019,
#   None,
#   'Drama,War'),
#  ('tt0787442', 'The Attack', 'The Attack', 2012, 102.0, 'Drama,Mystery,War'),
#  ('tt0787474',
#   'The Boxtrolls',
#   'The Boxtrolls',
#   2014,
#   96.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0787524',
#   'The Man Who Knew Infinity',
#   'The Man Who Knew Infinity',
#   2015,
#   108.0,
#   'Biography,Drama'),
#  ('tt0790628',
#   'The Incredible Burt Wonderstone',
#   'The Incredible Burt Wonderstone',
#   2013,
#   100.0,
#   'Adventure,Comedy,Fantasy'),
#  ('tt0790636',
#   'Dallas Buyers Club',
#   'Dallas Buyers Club',
#   2013,
#   117.0,
#   'Biography,Drama'),
#  ('tt0790653', 'Elliot Loves', 'Elliot Loves', 2012, 92.0, 'Comedy,Romance'),
#  ('tt0790663',
#   'The First Grader',
#   'The First Grader',
#   2010,
#   103.0,
#   'Biography,Drama,Romance'),
#  ('tt0790724',
#   'Jack Reacher',
#   'Jack Reacher',
#   2012,
#   130.0,
#   'Action,Crime,Thriller'),
#  ('tt0790736', 'R.I.P.D.', 'R.I.P.D.', 2013, 96.0, 'Action,Adventure,Comedy'),
#  ('tt0790770',
#   'Miles Ahead',
#   'Miles Ahead',
#   2015,
#   100.0,
#   'Biography,Drama,Music'),
#  ('tt0790788',
#   'The Yellow Wallpaper',
#   'The Yellow Wallpaper',
#   2012,
#   115.0,
#   'Thriller'),
#  ('tt0795459',
#   'Wilde Salomé',
#   'Wilde Salomé',
#   2011,
#   95.0,
#   'Documentary,Drama'),
#  ('tt0795461', 'Scary Movie 5', 'Scary Movie 5', 2013, 86.0, 'Comedy'),
#  ('tt0798817', '13', '13', 2010, 91.0, 'Drama,Thriller'),
#  ('tt0800054', 'The Guardians', 'The Guardians', 2010, 88.0, 'Comedy,Family'),
#  ('tt0800092', 'Ironmen', 'Ironmen', 2010, 119.0, 'Biography,Drama'),
#  ('tt0800320',
#   'Clash of the Titans',
#   'Clash of the Titans',
#   2010,
#   106.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0800325', 'The Dirt', 'The Dirt', 2019, 107.0, 'Biography,Comedy,Drama'),
#  ('tt0800353', 'Nemesis', 'Nemesis', 2010, 83.0, 'Drama'),
#  ('tt0800369', 'Thor', 'Thor', 2011, 115.0, 'Action,Adventure,Fantasy'),
#  ('tt0803061', 'Red Dog', 'Red Dog', 2011, 92.0, 'Biography,Comedy,Drama'),
#  ('tt0803096',
#   'Warcraft',
#   'Warcraft',
#   2016,
#   123.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0804463',
#   "Devil's Knot",
#   "Devil's Knot",
#   2013,
#   114.0,
#   'Biography,Crime,Drama'),
#  ('tt0804483', 'Folk!', 'Folk!', 2010, None, 'Documentary'),
#  ('tt0804497',
#   "It's Kind of a Funny Story",
#   "It's Kind of a Funny Story",
#   2010,
#   101.0,
#   'Comedy,Drama,Romance'),
#  ('tt0804509', 'The Mule', 'La mula', 2013, 100.0, 'Comedy,Drama'),
#  ('tt0805617', 'Spoon', 'Spoon', 2011, None, 'Action,Drama,Fantasy'),
#  ('tt0805647',
#   'The Witches',
#   'The Witches',
#   2020,
#   None,
#   'Adventure,Comedy,Family'),
#  ('tt0808245',
#   'A Letter to Elia',
#   'A Letter to Elia',
#   2010,
#   60.0,
#   'Documentary'),
#  ('tt0808447',
#   'The Last Pogo Jumps Again',
#   'The Last Pogo Jumps Again',
#   2013,
#   200.0,
#   'Documentary,Music'),
#  ('tt0808510',
#   'Tooth Fairy',
#   'Tooth Fairy',
#   2010,
#   101.0,
#   'Comedy,Family,Fantasy'),
#  ('tt0810772',
#   'Belle du Seigneur',
#   'Belle du Seigneur',
#   2012,
#   104.0,
#   'Drama,Romance'),
#  ('tt0810815', 'Cross the Line', 'Cross the Line', 2010, 87.0, 'Action'),
#  ('tt0810819',
#   'The Danish Girl',
#   'The Danish Girl',
#   2015,
#   119.0,
#   'Biography,Drama,Romance'),
#  ('tt0810856',
#   'Eyes of the Mothman',
#   'Eyes of the Mothman',
#   2011,
#   150.0,
#   'Documentary'),
#  ('tt0810913', 'Jack and Jill', 'Jack and Jill', 2011, 91.0, 'Comedy'),
#  ('tt0810922',
#   'Take Me Home Tonight',
#   'Take Me Home Tonight',
#   2011,
#   97.0,
#   'Comedy,Drama,Romance'),
#  ('tt0811021',
#   'Plumíferos - Aventuras voladoras',
#   'Plumíferos - Aventuras voladoras',
#   2010,
#   80.0,
#   'Adventure,Animation,Family'),
#  ('tt0811069', 'Lavoe', 'The King Hector Lavoe', 2011, 90.0, 'Drama,Music'),
#  ('tt0811137',
#   'The Do-Deca-Pentathlon',
#   'The Do-Deca-Pentathlon',
#   2012,
#   76.0,
#   'Comedy'),
#  ('tt0811613', 'Meridian Lines', 'Meridian Lines', 2013, None, 'Drama'),
#  ('tt0813992', 'American Flyer', 'American Flyer', 2010, 100.0, 'Adventure'),
#  ('tt0814255',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   2010,
#   118.0,
#   'Adventure,Family,Fantasy'),
#  ('tt0815101', 'Ashes', 'Ashes', 2010, 77.0, 'Drama'),
#  ('tt0815236',
#   "She's Out of My League",
#   "She's Out of My League",
#   2010,
#   104.0,
#   'Comedy,Romance'),
#  ('tt0816362',
#   'Card Subject to Change',
#   'Card Subject to Change',
#   2010,
#   87.0,
#   'Documentary'),
#  ('tt0816442', 'The Book Thief', 'The Book Thief', 2013, 131.0, 'Drama,War'),
#  ('tt0816462',
#   'Conan the Barbarian',
#   'Conan the Barbarian',
#   2011,
#   113.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0816648', 'Shanghai Hotel', 'Shanghai Hotel', 2011, 110.0, 'Drama'),
#  ('tt0816692',
#   'Interstellar',
#   'Interstellar',
#   2014,
#   169.0,
#   'Adventure,Drama,Sci-Fi'),
#  ('tt0816711',
#   'World War Z',
#   'World War Z',
#   2013,
#   116.0,
#   'Action,Adventure,Horror'),
#  ('tt0817177', 'Flipped', 'Flipped', 2010, 90.0, 'Comedy,Drama,Romance'),
#  ('tt0817230',
#   "Valentine's Day",
#   "Valentine's Day",
#   2010,
#   125.0,
#   'Comedy,Romance'),
#  ('tt0817545',
#   'The Power of Few',
#   'The Power of Few',
#   2013,
#   96.0,
#   'Action,Crime,Drama'),
#  ('tt0818098', 'Dreamkiller', 'Dreamkiller', 2010, 110.0, 'Thriller'),
#  ('tt0818172', 'Soupernatural', 'Soupernatural', 2010, None, 'Drama'),
#  ('tt0821486',
#   'Manhattan Minutiae',
#   'Manhattan Minutiae',
#   2016,
#   99.0,
#   'Comedy,Music,Romance'),
#  ('tt0822847', 'Priest', 'Priest', 2011, 87.0, 'Action,Adventure,Fantasy'),
#  ('tt0825282', 'The Long Falling', 'Où va la nuit', 2011, 105.0, 'Drama'),
#  ('tt0825283',
#   'Maximum Ride',
#   'Maximum Ride',
#   2016,
#   88.0,
#   'Action,Adventure,Comedy'),
#  ('tt0825334',
#   'Caravaggio and My Mother the Pope',
#   'Caravaggio and My Mother the Pope',
#   2018,
#   90.0,
#   'Comedy,Drama'),
#  ('tt0826532',
#   'Return to Yucca Flats: Desert Man-Beast',
#   'Return to Yucca Flats: Desert Man-Beast',
#   2010,
#   79.0,
#   'Comedy,Horror'),
#  ('tt0826823', 'Magic', 'Magic', 2010, None, 'Adventure,Family'),
#  ('tt0828135',
#   'Wild in the Streets',
#   'Wild in the Streets',
#   2012,
#   82.0,
#   'Documentary'),
#  ('tt0829150',
#   'Dracula Untold',
#   'Dracula Untold',
#   2014,
#   92.0,
#   'Action,Drama,Fantasy'),
#  ('tt0829176',
#   'Gallowwalkers',
#   'Gallowwalkers',
#   2012,
#   90.0,
#   'Action,Horror,Thriller'),
#  ('tt0831280', 'Waking Madison', 'Waking Madison', 2010, 89.0, 'Drama'),
#  ('tt0831387', 'Godzilla', 'Godzilla', 2014, 123.0, 'Action,Adventure,Sci-Fi'),
#  ('tt0831881', 'Land', 'Land', 2010, 76.0, 'Documentary'),
#  ('tt0835418', 'The Babymakers', 'The Babymakers', 2012, 95.0, 'Comedy'),
#  ('tt0835775',
#   'Electric Slide',
#   'Electric Slide',
#   2014,
#   95.0,
#   'Action,Biography,Crime'),
#  ('tt0835802', 'Krystal', 'Krystal', 2017, 90.0, 'Comedy,Drama'),
#  ('tt0837156',
#   "Pee-wee's Big Holiday",
#   "Pee-wee's Big Holiday",
#   2016,
#   90.0,
#   'Adventure,Comedy,Family'),
#  ('tt0837559',
#   'Approaching Midnight',
#   'Approaching Midnight',
#   2013,
#   86.0,
#   'Crime,Drama,Romance'),
#  ('tt0837562',
#   'Hotel Transylvania',
#   'Hotel Transylvania',
#   2012,
#   91.0,
#   'Animation,Comedy,Family'),
#  ('tt0837563',
#   'Pet Sematary',
#   'Pet Sematary',
#   2019,
#   101.0,
#   'Horror,Mystery,Thriller'),
#  ('tt0838194', 'Retreat!', 'Retreat!', 2016, None, 'Comedy,Drama,War'),
#  ('tt0839742',
#   'Bhopal: A Prayer for Rain',
#   'Bhopal: A Prayer for Rain',
#   2014,
#   96.0,
#   'Drama'),
#  ('tt0840358',
#   'Everyday Sunshine: The Story of Fishbone',
#   'Everyday Sunshine: The Story of Fishbone',
#   2010,
#   107.0,
#   'Documentary,Music'),
#  ('tt0840361', 'The Town', 'The Town', 2010, 125.0, 'Crime,Drama,Thriller'),
#  ('tt0840789', 'Río de oro', 'Río de oro', 2010, None, 'Western'),
#  ('tt0841185',
#   'Whatever Happened to Pete Blaggit?',
#   'Whatever Happened to Pete Blaggit?',
#   2012,
#   94.0,
#   'Comedy,Sci-Fi'),
#  ('tt0842926',
#   'The Kids Are All Right',
#   'The Kids Are All Right',
#   2010,
#   106.0,
#   'Comedy,Drama,Romance'),
#  ('tt0843839',
#   'The Fallen Word',
#   'The Fallen Word',
#   2013,
#   60.0,
#   'Drama,Fantasy,Mystery'),
#  ('tt0844699',
#   "Ivan Mosjoukine ou L'enfant du carnaval",
#   "Ivan Mosjoukine ou L'enfant du carnaval",
#   2016,
#   67.0,
#   'Documentary'),
#  ('tt0844866',
#   'Killer by Nature',
#   'Killer by Nature',
#   2010,
#   94.0,
#   'Adventure,Crime,Drama'),
#  ('tt0844915', 'Pox', 'Pox', 2011, 100.0, 'Comedy,Sci-Fi'),
#  ('tt0844993',
#   'Hoodwinked Too! Hood vs. Evil',
#   'Hoodwinked Too! Hood vs. Evil',
#   2011,
#   86.0,
#   'Animation,Comedy,Crime'),
#  ('tt0846004', 'Gangster Exchange', 'Gangster Exchange', 2010, 95.0, 'Action'),
#  ('tt0847180', 'Loot', 'Loot', 2011, 110.0, 'Action,Comedy,Crime'),
#  ('tt0847215', 'Neowolf', 'Neowolf', 2010, 88.0, 'Horror,Thriller'),
#  ('tt0847505', 'Night Traveler', 'Night Traveler', 2013, None, 'Adventure'),
#  ('tt0847735', 'Fun in the Army', 'Fauj Mein Mauj', 2010, None, 'Comedy'),
#  ('tt0847825',
#   'The Speed of Thought',
#   'The Speed of Thought',
#   2011,
#   93.0,
#   'Sci-Fi,Thriller'),
#  ('tt0848228',
#   'The Avengers',
#   'The Avengers',
#   2012,
#   143.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0848537', 'Epic', 'Epic', 2013, 102.0, 'Adventure,Animation,Family'),
#  ('tt0848554', 'The Sighting', 'Travis', 2016, 98.0, 'Horror,Sci-Fi,Thriller'),
#  ('tt0849437',
#   'Duel of Legends',
#   'Duel of Legends',
#   2018,
#   None,
#   'Action,Drama,Sport'),
#  ('tt0850247', 'Amsteroid', 'Amsteroid', 2018, 98.0, 'Sci-Fi'),
#  ('tt0850677',
#   'Jack & Diane',
#   'Jack & Diane',
#   2012,
#   110.0,
#   'Drama,Horror,Romance'),
#  ('tt0850678', 'Jackson Arms', 'Jackson Arms', 2015, 90.0, 'Romance'),
#  ('tt0850709', 'Risen', 'Risen', 2010, 121.0, 'Biography,Drama'),
#  ('tt0851471',
#   'Sir Billi',
#   'Sir Billi',
#   2012,
#   76.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0852441', 'Folie à deux', 'Folie à deux', 2012, None, 'Drama'),
#  ('tt0852939', 'Bloudím', 'Bloudím', 2010, 75.0, 'Drama'),
#  ('tt0852986', 'Naked Run', 'Naked Run', 2011, 84.0, 'Comedy'),
#  ('tt0853002', 'A Summer Song', 'A Summer Song', 2010, None, 'Drama'),
#  ('tt0853155',
#   'This Is What Love in Action Looks Like',
#   'This Is What Love in Action Looks Like',
#   2011,
#   74.0,
#   'Documentary'),
#  ('tt0856796', 'Kolorádó Kid', 'Kolorádó Kid', 2010, 111.0, 'Drama,Romance'),
#  ('tt0857190',
#   'The Sweeney',
#   'The Sweeney',
#   2012,
#   112.0,
#   'Action,Crime,Drama'),
#  ('tt0858411',
#   '2001 Maniacs: Field of Screams',
#   '2001 Maniacs: Field of Screams',
#   2010,
#   84.0,
#   'Comedy,Horror'),
#  ('tt0858419', 'Bolden', 'Bolden', 2019, 108.0, 'Drama'),
#  ('tt0858422',
#   'Immortal Island',
#   'Immortal Island',
#   2011,
#   84.0,
#   'Adventure,Horror,Thriller'),
#  ('tt0858500',
#   'Wide Blue Yonder',
#   'Wide Blue Yonder',
#   2010,
#   82.0,
#   'Comedy,Drama'),
#  ('tt0859612',
#   'The Golden Greek: The Harry Agganis Story',
#   'The Golden Greek: The Harry Agganis Story',
#   2010,
#   None,
#   'Documentary'),
#  ('tt0859635',
#   'Super Troopers 2',
#   'Super Troopers 2',
#   2018,
#   99.0,
#   'Comedy,Crime,Mystery'),
#  ('tt0860907',
#   'Evangelion: 3.0 You Can (Not) Redo',
#   'Evangerion shin gekijôban: Kyu',
#   2012,
#   96.0,
#   'Action,Animation,Drama'),
#  ('tt0861747', 'Zenitram', 'Zenitram', 2010, 103.0, 'Action,Adventure,Comedy'),
#  ('tt0862748',
#   'Lupin the 3rd',
#   'Rupan sansei',
#   2014,
#   133.0,
#   'Action,Adventure,Comedy'),
#  ('tt0862930', 'Dukun', 'Dukun', 2018, 108.0, 'Horror,Thriller'),
#  ('tt0864835',
#   'Mr. Peabody & Sherman',
#   'Mr. Peabody & Sherman',
#   2014,
#   92.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0865557', 'Letting Go', 'Letting Go', 2012, 83.0, 'Drama,Romance'),
#  ('tt0865561', '6 Month Rule', '6 Month Rule', 2011, 100.0, 'Comedy'),
#  ('tt0865911', 'Catharsis', 'Katharsis', 2011, 89.0, 'Mystery'),
#  ('tt0870154', 'Jungle Cruise', 'Jungle Cruise', 2020, None, 'Adventure'),
#  ('tt0870208', 'Touch Wood', 'Touch Wood', 2010, None, 'Comedy'),
#  ('tt0871891',
#   'The Nightclub Days',
#   'The Nightclub Days',
#   2012,
#   None,
#   'Comedy'),
#  ('tt0871893',
#   'Surprise, Surprise',
#   'Surprise, Surprise',
#   2010,
#   83.0,
#   'Drama'),
#  ('tt0872230',
#   'My Soul to Take',
#   'My Soul to Take',
#   2010,
#   107.0,
#   'Horror,Mystery,Thriller'),
#  ('tt0873886', 'Red State', 'Red State', 2011, 88.0, 'Action,Crime,Horror'),
#  ('tt0874268', 'The Dot Man', 'The Dot Man', 2017, None, 'Drama,Thriller'),
#  ('tt0874421', 'Beijing Taxi', 'Beijing Taxi', 2010, 78.0, 'Documentary'),
#  ('tt0874426',
#   'The Secret Philosophy',
#   'The Secret Philosophy',
#   2010,
#   90.0,
#   'Thriller'),
#  ('tt0875612',
#   "Rain Falls from Earth: Surviving Cambodia's Darkest Hour",
#   "Rain Falls from Earth: Surviving Cambodia's Darkest Hour",
#   2011,
#   None,
#   'Documentary'),
#  ('tt0875613', 'Rift', 'Rift', 2011, 100.0, 'Horror,Thriller'),
#  ('tt0875702',
#   'Bury the Hatchet',
#   'Bury the Hatchet',
#   2010,
#   120.0,
#   'Documentary'),
#  ('tt0877604', 'Chûshingura', 'Chûshingura', 2016, 76.0, None),
#  ('tt0878654', 'Bulletface', 'Bulletface', 2010, 82.0, 'Thriller'),
#  ('tt0878672', 'First Circle', 'First Circle', 2010, 72.0, 'Documentary'),
#  ('tt0878814', 'Jewtopia', 'Jewtopia', 2012, 90.0, 'Comedy,Romance'),
#  ('tt0878835', 'Please Give', 'Please Give', 2010, 87.0, 'Comedy,Drama'),
#  ('tt0879405', "Harm's Way", "Harm's Way", 2010, 82.0, 'Thriller'),
#  ('tt0879859', 'Torn', 'Torn', 2010, None, 'Thriller'),
#  ('tt0879870', 'Eat Pray Love', 'Eat Pray Love', 2010, 133.0, 'Drama,Romance'),
#  ('tt0880569',
#   'Mama I Want to Sing',
#   'Mama I Want to Sing',
#   2011,
#   100.0,
#   'Musical'),
#  ('tt0881320', 'Sanctum', 'Sanctum', 2011, 108.0, 'Adventure,Drama,Thriller'),
#  ('tt0882741',
#   'AIR: The Musical',
#   'AIR: The Musical',
#   2010,
#   100.0,
#   'Comedy,Musical,Romance'),
#  ('tt0882977', 'Snitch', 'Snitch', 2013, 112.0, 'Action,Drama,Thriller'),
#  ('tt0884214', 'Wreckage', 'Wreckage', 2010, 87.0, 'Horror,Thriller'),
#  ('tt0884325', 'Drain Baby', 'Drain Baby', 2011, None, 'Horror'),
#  ('tt0884726',
#   "Legends of Oz: Dorothy's Return",
#   "Legends of Oz: Dorothy's Return",
#   2013,
#   88.0,
#   'Adventure,Animation,Family'),
#  ('tt0884732',
#   'The Wedding Ringer',
#   'The Wedding Ringer',
#   2015,
#   101.0,
#   'Comedy'),
#  ('tt0887143', 'Hyenas', 'Hyenas', 2011, 92.0, 'Horror'),
#  ('tt0887161', 'Repo', 'Repo', 2010, 97.0, 'Comedy,Drama'),
#  ('tt0887266', 'Rollerboy', 'Rollerboy', 2013, 81.0, 'Documentary'),
#  ('tt0887751', 'Honor', 'Kavod', 2010, 118.0, 'Crime,Drama,Thriller'),
#  ('tt0889573',
#   'The Switch',
#   'The Switch',
#   2010,
#   101.0,
#   'Comedy,Drama,Romance'),
#  ('tt0891581',
#   'RxCannabis: A Freedom Tale',
#   'RxCannabis: A Freedom Tale',
#   2018,
#   83.0,
#   'Documentary'),
#  ('tt0892062',
#   'Hamlet A.D.D.',
#   'Hamlet A.D.D.',
#   2014,
#   95.0,
#   'Animation,Comedy,Fantasy'),
#  ('tt0892077',
#   'Gun of the Black Sun',
#   'Gun of the Black Sun',
#   2011,
#   90.0,
#   'Fantasy'),
#  ('tt0892318',
#   'Letters to Juliet',
#   'Letters to Juliet',
#   2010,
#   105.0,
#   'Adventure,Comedy,Drama'),
#  ('tt0892769',
#   'How to Train Your Dragon',
#   'How to Train Your Dragon',
#   2010,
#   98.0,
#   'Action,Adventure,Animation'),
#  ('tt0892791',
#   'Shrek Forever After',
#   'Shrek Forever After',
#   2010,
#   93.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0893310', 'Blur', 'Blur', 2011, 90.0, 'Drama,Mystery,Thriller'),
#  ('tt0893412',
#   'From Prada to Nada',
#   'From Prada to Nada',
#   2011,
#   107.0,
#   'Comedy,Drama,Romance'),
#  ('tt0896872',
#   'The Whistleblower',
#   'The Whistleblower',
#   2010,
#   112.0,
#   'Action,Biography,Crime'),
#  ('tt0899145', "Don't Fade Away", "Don't Fade Away", 2010, 89.0, 'Drama'),
#  ('tt0899154',
#   'The Key Man',
#   'The Key Man',
#   2011,
#   80.0,
#   'Crime,Drama,Thriller'),
#  ('tt0900387',
#   'Suite Française',
#   'Suite Française',
#   2014,
#   107.0,
#   'Drama,Romance,War'),
#  ('tt0901504', 'Psych:9', 'Psych:9', 2010, 98.0, 'Horror,Mystery,Thriller'),
#  ('tt0902247',
#   'Acts of Violence',
#   'Acts of Violence',
#   2010,
#   None,
#   'Crime,Drama,Thriller'),
#  ('tt0903036',
#   'Westbrick Murders',
#   'Westbrick Murders',
#   2010,
#   90.0,
#   'Action,Crime,Thriller'),
#  ('tt0903624',
#   'The Hobbit: An Unexpected Journey',
#   'The Hobbit: An Unexpected Journey',
#   2012,
#   169.0,
#   'Adventure,Family,Fantasy'),
#  ('tt0903657',
#   'Love & Mercy',
#   'Love & Mercy',
#   2014,
#   121.0,
#   'Biography,Drama,Music'),
#  ('tt0905372', 'The Thing', 'The Thing', 2011, 103.0, 'Horror,Mystery,Sci-Fi'),
#  ('tt0906013', 'The Grind', 'The Grind', 2012, 85.0, 'Crime,Thriller'),
#  ('tt0906327', "The Unlikely's", "The Unlikely's", 2016, None, 'Comedy'),
#  ('tt0906778',
#   'Black Butterflies',
#   'Black Butterflies',
#   2011,
#   100.0,
#   'Biography,Drama'),
#  ('tt0907305', 'Prey', 'Proie', 2010, 90.0, 'Adventure,Drama,Horror'),
#  ('tt0907731', 'Eager to Die', 'Eager to Die', 2010, 109.0, 'Drama,Thriller'),
#  ('tt0907852', 'Exposed', 'Exposed', 2012, 82.0, 'Drama,Mystery,Thriller'),
#  ('tt0910885',
#   "A Merry Friggin' Christmas",
#   "A Merry Friggin' Christmas",
#   2014,
#   88.0,
#   'Comedy'),
#  ('tt0910926', "Movin' In", "Movin' In", 2010, 95.0, 'Comedy,Romance'),
#  ('tt0914823',
#   'House Under Siege',
#   'House Under Siege',
#   2010,
#   78.0,
#   'Action,Thriller'),
#  ('tt0914852', 'Monkeyman935', 'Monkeyman935', 2010, None, 'Horror'),
#  ('tt0914863',
#   'Unthinkable',
#   'Unthinkable',
#   2010,
#   97.0,
#   'Crime,Drama,Thriller'),
#  ('tt0915463',
#   'Jackboots on Whitehall',
#   'Jackboots on Whitehall',
#   2010,
#   91.0,
#   'Animation,Comedy,Sci-Fi'),
#  ('tt0918520',
#   'Gangster Kittens',
#   'Gangster Kittens',
#   2016,
#   None,
#   'Drama,Thriller'),
#  ('tt0918553', 'Periphery', 'Periphery', 2011, None, 'Drama'),
#  ('tt0918575', 'Victim', 'Victim', 2010, 90.0, 'Horror,Thriller'),
#  ('tt0918940',
#   'The Legend of Tarzan',
#   'The Legend of Tarzan',
#   2016,
#   110.0,
#   'Action,Adventure,Drama'),
#  ('tt0920459',
#   'The Happy Housewife',
#   'De gelukkige huisvrouw',
#   2010,
#   100.0,
#   'Comedy,Drama,Romance'),
#  ('tt0923653',
#   'The Dead Undead',
#   'The Dead Undead',
#   2010,
#   89.0,
#   'Action,Horror,Sci-Fi'),
#  ('tt0923954',
#   'Truth About Kerry',
#   'Truth About Kerry',
#   2010,
#   84.0,
#   'Drama,Mystery,Thriller'),
#  ('tt0924266',
#   'Pizza with Bullets',
#   'Pizza with Bullets',
#   2010,
#   99.0,
#   'Comedy'),
#  ('tt0926084',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   2010,
#   146.0,
#   'Adventure,Fantasy,Mystery'),
#  ('tt0926132',
#   'Road to Red',
#   'Road to Red',
#   2016,
#   120.0,
#   'Action,Adventure,Horror'),
#  ('tt0926170',
#   "White Men Can't Dance",
#   "White Men Can't Dance",
#   2012,
#   105.0,
#   'Drama,Family'),
#  ('tt0929618', 'The Penthouse', 'The Penthouse', 2010, 89.0, 'Comedy'),
#  ('tt0929742', 'Deep Gold 3D', 'Deep Gold', 2011, 86.0, 'Action'),
#  ('tt0932667',
#   'The Man in the Silo',
#   'The Man in the Silo',
#   2016,
#   55.0,
#   'Drama'),
#  ('tt0933876', 'June 9', 'June 9', 2018, 95.0, 'Horror,Mystery,Thriller'),
#  ('tt0934446',
#   'Glenn, the Flying Robot',
#   'Glenn, the Flying Robot',
#   2010,
#   85.0,
#   'Drama,Sci-Fi'),
#  ('tt0934981', 'The Waiter', 'The Waiter', 2010, 92.0, 'Action,Crime,Drama'),
#  ('tt0935075', 'Rabbit Hole', 'Rabbit Hole', 2010, 91.0, 'Drama'),
#  ('tt0937225', 'Joe Dick', 'Joe Dick', 2017, 96.0, 'Comedy'),
#  ('tt0937353',
#   "The Devil's Flower",
#   'Tsvetok dyavola',
#   2010,
#   90.0,
#   'Mystery,Romance'),
#  ('tt0938283',
#   'The Last Airbender',
#   'The Last Airbender',
#   2010,
#   103.0,
#   'Action,Adventure,Family'),
#  ('tt0938305',
#   'Freaky Deaky',
#   'Freaky Deaky',
#   2012,
#   90.0,
#   'Comedy,Crime,Thriller'),
#  ('tt0938330',
#   'Silent Hill: Revelation',
#   'Silent Hill: Revelation',
#   2012,
#   95.0,
#   'Horror'),
#  ('tt0940656',
#   'Arthur 3: The War of the Two Worlds',
#   'Arthur 3: la guerre des deux mondes',
#   2010,
#   101.0,
#   'Adventure,Animation,Family'),
#  ('tt0942906',
#   'White Knuckles',
#   'White Knuckles',
#   2010,
#   88.0,
#   'Drama,Thriller'),
#  ('tt0944835', 'Salt', 'Salt', 2010, 100.0, 'Action,Mystery,Thriller'),
#  ('tt0945513',
#   'Source Code',
#   'Source Code',
#   2011,
#   93.0,
#   'Action,Drama,Sci-Fi'),
#  ('tt0947798', 'Black Swan', 'Black Swan', 2010, 108.0, 'Drama,Thriller'),
#  ('tt0947810',
#   'Green Zone',
#   'Green Zone',
#   2010,
#   115.0,
#   'Action,Drama,Thriller'),
#  ('tt0948470',
#   'The Amazing Spider-Man',
#   'The Amazing Spider-Man',
#   2012,
#   136.0,
#   'Action,Adventure,Sci-Fi'),
#  ('tt0949872', 'Coffee Sex You', 'Coffee Sex You', 2014, 88.0, 'Drama'),
#  ('tt0954947',
#   'The Killer Inside Me',
#   'The Killer Inside Me',
#   2010,
#   109.0,
#   'Crime,Drama,Horror'),
#  ('tt0955308',
#   'Robin Hood',
#   'Robin Hood',
#   2010,
#   140.0,
#   'Action,Adventure,Drama'),
#  ('tt0959306', 'Reach Me', 'Reach Me', 2014, 95.0, 'Comedy,Crime,Drama'),
#  ('tt0959329', 'Nine Dead', 'Nine Dead', 2010, 98.0, 'Crime,Drama,Horror'),
#  ('tt0960067', 'Heart of Now', 'Heart of Now', 2010, 90.0, 'Drama'),
#  ('tt0960727', 'Let Me Survive', 'Let Me Survive', 2013, None, 'Drama'),
#  ('tt0960730',
#   'Beautiful Darling',
#   'Beautiful Darling',
#   2010,
#   85.0,
#   'Documentary'),
#  ('tt0960827',
#   'Private Security Officer: Los Angeles',
#   'Private Security Officer: Los Angeles',
#   2010,
#   84.0,
#   'Action,Comedy,Crime'),
#  ('tt0960864',
#   'Truth in Numbers? Everything, According to Wikipedia',
#   'Truth in Numbers? Everything, According to Wikipedia',
#   2010,
#   85.0,
#   'Documentary'),
#  ('tt0961036', 'Avenge', 'Avenge', 2014, 88.0, 'Drama'),
#  ('tt0961097',
#   'A Monster in Paris',
#   'Un monstre à Paris',
#   2011,
#   90.0,
#   'Adventure,Animation,Comedy'),
#  ('tt0961725', 'Devour', 'Devour', 2011, None, 'Horror'),
#  ('tt0961755',
#   'The Trouble with Cali',
#   'The Trouble with Cali',
#   2012,
#   None,
#   'Comedy'),
#  ('tt0962764', 'The House of Sun', 'Dom Solntsa', 2010, 110.0, 'Drama'),
#  ('tt0963177', 'Made in Romania', 'Made in Romania', 2010, 95.0, 'Comedy'),
#  ('tt0963292',
#   'Feast of the Assumption: BTK and the Otero Family Murders',
#   'Feast of the Assumption: The Otero Family Murders',
#   2010,
#   86.0,
#   'Crime,Documentary'),
#  ('tt0963966',
#   "The Sorcerer's Apprentice",
#   "The Sorcerer's Apprentice",
#   2010,
#   109.0,
#   'Action,Adventure,Family'),
#  ('tt0964517',
#   'The Fighter',
#   'The Fighter',
#   2010,
#   116.0,
#   'Biography,Drama,Sport'),
#  ('tt0964544',
#   "Pushin' Up Daisies",
#   "Pushin' Up Daisies",
#   2010,
#   87.0,
#   'Comedy'),
#  ('tt0965424',
#   'Have You Heard from Johannesburg: Hell of a Job',
#   'Have You Heard from Johannesburg: Hell of a Job',
#   2010,
#   57.0,
#   'Documentary'),
#  ('tt0965425',
#   'Have You Heard from Johannesburg: Road to Resistance',
#   'Have You Heard from Johannesburg: Road to Resistance',
#   2010,
#   65.0,
#   'Documentary'),
#  ('tt0965429',
#   "L'imbroglio nel lenzuolo",
#   "L'imbroglio nel lenzuolo",
#   2010,
#   105.0,
#   'Comedy,Romance'),
#  ('tt0968264',
#   'The Conspirator',
#   'The Conspirator',
#   2010,
#   122.0,
#   'Crime,Drama,History'),
#  ('tt0969332',
#   'Little Witch on a Broomstick',
#   'Saxána a Lexikon kouzel',
#   2011,
#   90.0,
#   'Animation,Comedy,Family'),
#  ('tt0969345',
#   'Strange Frame: Love & Sax',
#   'Strange Frame: Love & Sax',
#   2012,
#   98.0,
#   'Animation,Crime,Music'),
#  ('tt0969653',
#   'White Wall',
#   'White Wall',
#   2010,
#   91.0,
#   'Action,Mystery,Sci-Fi'),
#  ('tt0970179', 'Hugo', 'Hugo', 2011, 126.0, 'Adventure,Drama,Family'),
#  ('tt0970866',
#   'Little Fockers',
#   'Little Fockers',
#   2010,
#   98.0,
#   'Comedy,Romance'),
#  ('tt0970926',
#   'The Chosen One',
#   'The Chosen One',
#   2010,
#   101.0,
#   'Comedy,Drama'),
#  ('tt0970955', 'The Reason', 'La razón', 2010, 70.0, 'Drama,Fantasy,History'),
#  ('tt0972544',
#   'Back Roads',
#   'Back Roads',
#   2018,
#   101.0,
#   'Crime,Drama,Thriller'),
#  ('tt0972815',
#   'Have You Heard from Johannesburg: Fair Play',
#   'Have You Heard from Johannesburg: Fair Play',
#   2010,
#   96.0,
#   'Documentary'),
#  ('tt0972816',
#   'Have You Heard from Johannesburg: The Bottom Line',
#   'Have You Heard from Johannesburg: The Bottom Line',
#   2010,
#   86.0,
#   'Documentary'),
#  ('tt0972848',
#   'Lives and Deaths of the Poets',
#   'Lives and Deaths of the Poets',
#   2011,
#   93.0,
#   'Comedy'),
#  ('tt0973809',
#   'Headhunter: The Assessment Weekend',
#   'Headhunter: The Assessment Weekend',
#   2010,
#   93.0,
#   'Action,Thriller'),
#  ('tt0974015',
#   'Justice League',
#   'Justice League',
#   2017,
#   120.0,
#   'Action,Adventure,Fantasy'),
#  ('tt0974584',
#   'Black Limousine',
# ...
#   'Ameddig bírjuk: Gemini 70 felett',
#   2019,
#   69.0,
#   'Documentary'),
#  ('tt10042824', 'Doña Julia', 'Doña Julia', 2015, 72.0, 'Documentary'),
#  ('tt10043058', 'The Kidnapper 2', 'The Kidnapper 2', 2016, None, 'Action'),
#  ('tt10043150',
#   'Frankenstein: Presented by the 4th Wall Players',
#   'Frankenstein: Presented by the 4th Wall Players',
#   2014,
#   None,
#   'Horror'),
#  ('tt10043212',
#   'Alle sorgenti della vita -Flora Gualdani',
#   'Alle sorgenti della vita -Flora Gualdani',
#   2019,
#   50.0,
#   'Documentary'),
#  ('tt10043732',
#   'Oblepikhovoe leto',
#   'Oblepikhovoe leto',
#   2018,
#   87.0,
#   'Biography,Drama'),
#  ('tt10043868', 'The Kidnapper 4', 'The Kidnapper 4', 2018, None, 'Action'),
#  ('tt10043990',
#   'Lo peor de los deseos',
#   'Lo peor de los deseos',
#   2018,
#   93.0,
#   'Thriller'),
#  ('tt10044000', 'Snow to Sand', 'Snow to Sand', 2019, 60.0, 'Documentary'),
#  ('tt10044182', 'Block Z', 'Block Z', 2019, None, 'Horror,Thriller'),
#  ('tt10044704',
#   'Between Maybes',
#   'Between Maybes',
#   2019,
#   107.0,
#   'Drama,Romance'),
#  ('tt10044934', 'Bumi Itu Bulat', 'Bumi Itu Bulat', 2019, 103.0, 'Drama'),
#  ('tt10045014', 'Rangu', 'Rangu', 2018, 156.0, 'Action'),
#  ('tt10045072',
#   'Billich: Beyond The Canvas',
#   'Billich: Beyond The Canvas',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10045134',
#   'Inside the Walls',
#   'Inside the Walls',
#   2017,
#   None,
#   'Drama,Horror,Mystery'),
#  ('tt10045136', 'War of Art', 'War of Art', 2019, 102.0, 'Documentary'),
#  ('tt10045260',
#   'The Exorcist III: Legion',
#   'The Exorcist III: Legion',
#   2016,
#   105.0,
#   'Horror'),
#  ('tt10045266', 'Butsaagui Amlalt', 'Butsaagui Amlalt', 2019, 95.0, 'Drama'),
#  ('tt10045422', 'Zwitscherland', 'Zwitscherland', 2018, None, 'Documentary'),
#  ('tt10045434', 'The Door', 'Kapi', 2019, 110.0, 'Comedy,Drama'),
#  ('tt10045444',
#   'Durs Appenzellerland',
#   'Durs Appenzellerland',
#   2018,
#   None,
#   'Documentary'),
#  ('tt10045828', 'Parallel Road', 'Parallel Road', 2017, 58.0, 'Documentary'),
#  ('tt10046208',
#   'La vida en común',
#   'La vida en común',
#   2019,
#   70.0,
#   'Drama,Mystery'),
#  ('tt10046236', 'Alem-i Cin 2', 'Alem-i Cin 2', 2019, 93.0, 'Horror'),
#  ('tt10047128',
#   'De hormigón armado',
#   'De hormigón armado',
#   2015,
#   90.0,
#   'Drama'),
#  ('tt10047356',
#   'Eises Kälte - Frozen in Time',
#   'Eises Kälte - Frozen in Time',
#   2018,
#   92.0,
#   'Mystery'),
#  ('tt10047768',
#   'Nikos Dragoumis: Enas zografos sti skia tis istorias (1874-1933)',
#   'Nikos Dragoumis: Enas zografos sti skia tis istorias (1874-1933)',
#   2015,
#   None,
#   'Biography,Documentary'),
#  ('tt10048028',
#   '¿Qué fue de Pavlosky?',
#   '¿Qué fue de Pavlosky?',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10048070', 'Gafas a ver', 'Gafas a ver', 2014, 73.0, 'Comedy,Drama'),
#  ('tt10048096', 'Rejected', 'Rechazados', 2018, None, 'Drama,Fantasy'),
#  ('tt10048332',
#   'Gente de Zona: En Letra De Otro',
#   'Gente de Zona: En Letra De Otro',
#   2018,
#   None,
#   'Documentary,Music'),
#  ('tt10048376',
#   'Ya podaryu tebe pobedu',
#   'Ya podaryu tebe pobedu',
#   2019,
#   101.0,
#   'Drama'),
#  ('tt10048408',
#   'La ola de crímenes',
#   'La ola de crímenes',
#   2017,
#   70.0,
#   'Drama'),
#  ('tt10048556', 'Staged Killer', 'Staged Killer', 2019, 88.0, 'Thriller'),
#  ('tt10048976',
#   'When Rumi meets Francis',
#   'When Rumi meets Francis',
#   2017,
#   51.0,
#   'Drama'),
#  ('tt10049110', 'Die Wiese', 'Die Wiese', 2019, 93.0, 'Documentary'),
#  ('tt10049152', 'Pur laine', 'Pur laine', 2018, 88.0, 'Comedy,Drama'),
#  ('tt10049176',
#   'Kids Of Wuzhumuqin Town',
#   'Kids Of Wuzhumuqin Town',
#   2015,
#   84.0,
#   'Drama,Family'),
#  ('tt10049210', 'The Sentries', 'The Sentries', 2018, 73.0, 'Family'),
#  ('tt10049238',
#   'Joan Miró, the inner fire',
#   'Miró contra Miró',
#   2018,
#   61.0,
#   'Documentary'),
#  ('tt10049262',
#   'James & Pat & Dave',
#   'James & Pat & Dave',
#   2019,
#   None,
#   'Comedy,Romance'),
#  ('tt10049768', 'Unarmed Man', 'Unarmed Man', 2019, None, 'Drama'),
#  ('tt10050098', 'Mr Misfortune', 'Mr Misfortune', 2019, 92.0, 'Thriller'),
#  ('tt10050150', 'Vaa Deal', 'Vaa Deal', 2019, None, 'Action'),
#  ('tt10050274', 'Mystified', 'Mystified', 2019, 86.0, 'Adventure,Fantasy'),
#  ('tt10050292', 'Reincarnation', 'Reincarnation', 2019, None, 'Drama'),
#  ('tt10050404',
#   'Tian Shang De Hai Zi',
#   'Tian Shang De Hai Zi',
#   2018,
#   None,
#   'Drama'),
#  ('tt10050592',
#   'The Age of Sebastian',
#   'The Age of Sebastian',
#   2018,
#   70.0,
#   'Drama'),
#  ('tt10050608', 'Drama', 'Drama', 2019, 117.0, 'Drama'),
#  ('tt10050612', "Bigfoot's Lament", "Bigfoot's Lament", 2019, 60.0, 'Fantasy'),
#  ('tt10050614', 'Arayakadavil', 'Arayakadavil', 2019, None, 'Drama'),
#  ('tt10050686',
#   'British Bungalow',
#   'British Bungalow',
#   2019,
#   117.0,
#   'Horror,Thriller'),
#  ('tt10050722', "Thing I Don't Get", "Thing I Don't Get", 2018, 71.0, 'Drama'),
#  ('tt10050738', 'Therottam', 'Therottam', 2019, 117.0, 'Action,Thriller'),
#  ('tt10050766',
#   'Brené Brown: The Call to Courage',
#   'Brené Brown: The Call to Courage',
#   2019,
#   76.0,
#   'Documentary,Drama'),
#  ('tt10050782',
#   'Grass is Greener',
#   'Grass is Greener',
#   2019,
#   97.0,
#   'Documentary'),
#  ('tt10050816', 'Fiancées', 'Fiancées', 2019, None, 'Documentary'),
#  ('tt10051124',
#   'Crossing the river of life',
#   'Crossing the river of life',
#   2018,
#   55.0,
#   'Documentary'),
#  ('tt10051320',
#   'Killing Your Daughter',
#   'Killing Your Daughter',
#   2019,
#   None,
#   'Thriller'),
#  ('tt10052156', 'Shell and Joint', 'Shell and Joint', 2018, 154.0, 'Drama'),
#  ('tt10052290',
#   'Love and Mercy',
#   'Milosc i milosierdzie',
#   2019,
#   104.0,
#   'Biography,Drama,Family'),
#  ('tt10052452',
#   "Jeremiah's Woods",
#   "Jeremiah's Woods",
#   2018,
#   83.0,
#   'Comedy,Horror'),
#  ('tt10053270', 'AB', 'AB', 2019, 48.0, 'Documentary'),
#  ('tt10054198',
#   'Vogel Lost Vogel',
#   'Ibed Fogel et Fogel',
#   2018,
#   55.0,
#   'Documentary'),
#  ('tt10054330', 'I Miss Oromia', 'I Miss Oromia', 2018, 86.0, 'Documentary'),
#  ('tt10054536', "Shiva's Daughter", "Shiva's Daughter", 2019, 88.0, 'Drama'),
#  ('tt10054544', 'VI', 'VI', 2019, None, 'Thriller'),
#  ('tt10054624',
#   'The Art of Directing: John Huston',
#   'The Art of Directing: John Huston',
#   2017,
#   75.0,
#   'Documentary'),
#  ('tt10054672',
#   'Young: Belljar of Ineffable Youth',
#   'Young: Belljar of Ineffable Youth',
#   2015,
#   130.0,
#   'Documentary'),
#  ('tt10054906', 'Ropani', 'Ropani', 2017, 27.0, 'Documentary,Musical'),
#  ('tt10054952',
#   '3D Print Masters',
#   '3D Print Masters',
#   2019,
#   52.0,
#   'Biography,Documentary'),
#  ('tt10055284',
#   'Ghost Town: The Curse of Bryerstone',
#   'Ghost Town: The Curse of Bryerstone',
#   2019,
#   None,
#   'Adventure'),
#  ('tt10055618',
#   'Tunguska Butterfly',
#   'Tsungûsuka batafurai: Saki to Mari no monogatari',
#   2019,
#   91.0,
#   None),
#  ('tt10055762',
#   'Mullapoo Viplavam',
#   'Mullapoo Viplavam',
#   2019,
#   136.0,
#   'Drama'),
#  ('tt10055770', 'Vellai Pookal', 'Vellaipookal', 2019, 122.0, 'Thriller'),
#  ('tt10055774',
#   'Mere Pyare Deshvasiyom',
#   'Mere Pyare Deshvasiyom',
#   2019,
#   110.0,
#   'Comedy'),
#  ('tt10056028',
#   'Fatei and the sea',
#   'Fatei and the sea',
#   2018,
#   None,
#   'Documentary'),
#  ('tt10056070',
#   'Das Bürgermeistermädchen',
#   'Das Bürgermeistermädchen',
#   2018,
#   57.0,
#   'Comedy,Drama'),
#  ('tt10056072', 'Calling', 'Calling', 2019, None, 'Crime'),
#  ('tt10056270',
#   'O Ballet de Hugo Bianchi',
#   'O Ballet de Hugo Bianchi',
#   2019,
#   None,
#   'Biography,Documentary'),
#  ('tt10056322', 'MeloDylan', 'MeloDylan', 2019, 92.0, 'Drama'),
#  ('tt10056330', 'Rotenberg', 'Rotenberg', 2018, 78.0, 'Documentary'),
#  ('tt10056334', 'Octubre', 'Octubre', 2018, 80.0, 'Documentary'),
#  ('tt10056452', 'Zombolicious', 'Zombolicious', 2019, None, 'Comedy'),
#  ('tt10056504',
#   'Walking Out',
#   'Walking Out',
#   2017,
#   118.0,
#   'Adventure,Drama,Mystery'),
#  ('tt10056564',
#   "La fin da la val l'è mia la fin dal mund",
#   "La fin da la val l'è mia la fin dal mund",
#   2018,
#   63.0,
#   'Documentary'),
#  ('tt10056728', 'Nourathar', 'Nourathar', 2014, 51.0, 'Documentary'),
#  ('tt10057076',
#   'As Cores da Serpente',
#   'As Cores da Serpente',
#   2019,
#   70.0,
#   'Documentary'),
#  ('tt10057466',
#   'The 500 Foot Sister',
#   'The 500 Foot Sister',
#   2019,
#   115.0,
#   'Animation'),
#  ('tt10057838', ';', ';', 2017, None, None),
#  ('tt10058356', 'Leur souffle', 'Leur souffle', 2019, 120.0, 'Documentary'),
#  ('tt10058744',
#   'Urgence de femme',
#   'Urgence de femme',
#   2016,
#   None,
#   'Documentary'),
#  ('tt10059220', 'Blood of God', 'Khoon-e Khoda', 2019, None, 'Drama'),
#  ('tt10059236',
#   'My Second Year in College',
#   'Sale dovom daneshkadeh man',
#   2019,
#   99.0,
#   'Drama'),
#  ('tt10059440',
#   'For The Voiceless',
#   'For The Voiceless',
#   2019,
#   119.0,
#   'Documentary'),
#  ('tt10059478',
#   'Frozen Faith: Cryonics and the Quest to Cheat Death',
#   'Frozen Faith: Cryonics and the Quest to Cheat Death',
#   2016,
#   None,
#   'Documentary'),
#  ('tt10059530',
#   'And the Winners Are!',
#   'And the Winners Are!',
#   2019,
#   82.0,
#   'Documentary'),
#  ('tt10059624', 'Heinz', 'Heinz', 2018, None, 'Animation'),
#  ('tt10059756',
#   "Bill Viola, expérience de l'infini",
#   "Bill Viola, expérience de l'infini",
#   2014,
#   52.0,
#   'Documentary'),
#  ('tt10060902',
#   'Second Hand Store Horror Tales',
#   'Second Hand Store Horror Tales',
#   2018,
#   None,
#   'Horror'),
#  ('tt10061256',
#   'Hot Gimmick: Girl Meets Boy',
#   'Hot Gimmick: Girl Meets Boy',
#   2019,
#   None,
#   'Drama'),
#  ('tt10061464', 'Invaded', 'Invaded', 2019, None, 'Thriller'),
#  ('tt10061766', 'Windfall', 'Windfall', 2019, None, 'Comedy,Crime,Drama'),
#  ('tt10062102',
#   'Jattan Diyan Dildariyan',
#   'Jattan Diyan Dildariyan',
#   2016,
#   None,
#   'Drama'),
#  ('tt10062150',
#   "Yücel'in Çiçekleri",
#   "Yücel'in Çiçekleri",
#   2018,
#   69.0,
#   'Documentary,History'),
#  ('tt10062286', 'Lustrum', 'Lustrum', 2018, 90.0, 'Documentary'),
#  ('tt10062474',
#   'Unmadiyude Maranam',
#   'Unmadiyude Maranam',
#   2019,
#   78.0,
#   'Fantasy'),
#  ('tt10062480',
#   "Vivre l'anarchie",
#   "Vivre l'anarchie",
#   2019,
#   90.0,
#   'Documentary'),
#  ('tt10062530', 'Canapa Nostra', 'Canapa Nostra', 2019, None, 'Documentary'),
#  ('tt10062546',
#   "Dreux, la vie d'après",
#   "Dreux, la vie d'après",
#   2017,
#   None,
#   'Documentary'),
#  ('tt10062556',
#   'Bhuj: The Pride of India',
#   'Bhuj: The Pride of India',
#   2020,
#   None,
#   'History'),
#  ('tt10062572',
#   'Bring Out Your Dead',
#   'Bring Out Your Dead',
#   2019,
#   None,
#   None),
#  ('tt10062606', 'Les Set Caixes', 'Les Set Caixes', 2017, 55.0, 'Documentary'),
#  ('tt10062650', 'O Olho e a Faca', 'O Olho e a Faca', 2018, 99.0, 'Drama'),
#  ('tt10062704', "Sasha's Hell", "Sasha's Hell", 2019, 98.0, 'Drama,Horror'),
#  ('tt10063028',
#   'Puck & Hans - Made in Holland',
#   'Puck & Hans - Made in Holland',
#   2019,
#   52.0,
#   'Documentary'),
#  ('tt10063078',
#   'Antropofaga Makumba',
#   'Antropofaga Makumba',
#   2018,
#   86.0,
#   'Drama'),
#  ('tt10063814',
#   'Cartas da Bessarábia',
#   'Cartas da Bessarábia',
#   2016,
#   None,
#   'Documentary'),
#  ('tt10063976', 'Knock Down', 'Knock Down', 2018, None, 'Documentary'),
#  ('tt10064326',
#   'Hypnotisøren og Danserinden',
#   'Hypnotisøren og Danserinden',
#   2020,
#   100.0,
#   'Drama'),
#  ('tt10064354', 'Inland', 'Inland', 2019, 95.0, 'Documentary'),
#  ('tt10064448',
#   'Because We Are Girls',
#   'Because We Are Girls',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10064536',
#   'Untitled Disney Marvel Film',
#   'Untitled Disney Marvel Film',
#   2022,
#   None,
#   'Action'),
#  ('tt10064558',
#   'Untitled Marvel Film',
#   'Untitled Marvel Film',
#   2021,
#   None,
#   'Action'),
#  ('tt10064562',
#   'Charismatic Megafauna',
#   'Charismatic Megafauna',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10064728',
#   'Inverse Everest',
#   'Inverse Everest',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10064828', 'Man on the Bus', 'Man on the Bus', 2019, 84.0, 'Documentary'),
#  ('tt10064948', 'Epokalipsa', 'Epokalipsa', 2019, 180.0, 'Horror'),
#  ('tt10065576',
#   'The Tiny Life of Butcher Duke',
#   'The Tiny Life of Butcher Duke',
#   2019,
#   78.0,
#   'Comedy'),
#  ('tt10065750',
#   'My Nudity Means Nothing',
#   'Ma nudité ne sert à rien',
#   2019,
#   85.0,
#   'Drama'),
#  ('tt10065960', 'Snatched', 'Snatched', 2016, 11.0, 'Drama'),
#  ('tt10065976',
#   'No Longer Human: Dazai Osamu and Three Women',
#   'No Longer Human',
#   2019,
#   None,
#   'Biography'),
#  ('tt10066102', 'Red Velvet', 'Red Velvet', 2018, 11.0, 'Drama'),
#  ('tt10066162', 'Song of Youth', 'Lao shi · Hao', 2019, None, 'Drama'),
#  ('tt10066186', '88A-12', '88A-12', 2016, 8.0, 'Fantasy'),
#  ('tt10066268', 'Despair', 'Despair', 2019, None, 'Drama'),
#  ('tt10066376', 'Goa Girls', 'Goa Girls', 2016, None, 'Romance'),
#  ('tt10066396',
#   'Dr Prasad c/o sitara',
#   'Dr Prasad c/o sitara',
#   2018,
#   97.0,
#   'Comedy,Horror,Thriller'),
#  ('tt10066526', 'Mantan Manten', 'Mantan Manten', 2019, 102.0, 'Drama'),
#  ('tt10066560', 'Innerscape', 'Innerscape', 2019, 80.0, 'Drama'),
#  ('tt10066628',
#   'Charlie Chaplin: The Making of a Genius',
#   'Charlie Chaplin: The Making of a Genius',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10066646', 'Agaton', 'Agaton', 2018, 45.0, 'Biography,Documentary,Drama'),
#  ('tt10066756',
#   'Miehiä ja poikia',
#   'Miehiä ja poikia',
#   2019,
#   85.0,
#   'Documentary'),
#  ('tt10066788',
#   'Blizhe, chem kazhetsya',
#   'Blizhe, chem kazhetsya',
#   2016,
#   None,
#   'Drama'),
#  ('tt10067502', 'Totally Crazy', 'Totally Crazy', 2017, 90.0, 'Musical'),
#  ('tt10068158',
#   "Made in Abyss: Journey's Dawn",
#   'Made in Abyss: Tabidachi no Yoake',
#   2019,
#   139.0,
#   'Adventure,Animation,Fantasy'),
#  ('tt10068184', 'Futari Ecchi', 'Futari Ecchi', 2019, None, 'Comedy,Romance'),
#  ('tt10068544',
#   'Made in Abyss: Wandering Twilight',
#   'Made in Abyss: Hôrô Suru Tasogare',
#   2019,
#   110.0,
#   'Adventure,Animation,Fantasy'),
#  ('tt10068916',
#   'Made in Abyss: Fukaki Tamashî no Reimei',
#   'Made in Abyss: Fukaki Tamashî no Reimei',
#   2020,
#   None,
#   'Adventure,Animation,Fantasy'),
#  ('tt1006907', 'Last Breath', 'Last Breath', 2010, 91.0, 'Horror'),
#  ('tt10069122', 'Senseless me', 'Senseless me', 2019, 84.0, 'Documentary'),
#  ('tt10069190', 'Bionic Showgirl', 'Bionic Showgirl', 2019, None, 'Musical'),
#  ('tt10069426',
#   'Myanmar: An Unholy Alliance',
#   'Myanmar: An Unholy Alliance',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10069476', 'Seytan-i Ins', 'Seytan-i Ins', 2019, 82.0, 'Horror'),
#  ('tt10069842', 'Iluze', 'Iluze', 2019, 60.0, 'Documentary'),
#  ('tt10069972', 'The Unbendable', 'The Unbendable', 2016, 75.0, 'Drama'),
#  ('tt1007029',
#   'The Iron Lady',
#   'The Iron Lady',
#   2011,
#   105.0,
#   'Biography,Drama'),
#  ('tt10071230',
#   'Good Girlfriend',
#   'Good Girlfriend',
#   2018,
#   None,
#   'Adult,Drama,Romance'),
#  ('tt10071262',
#   'Taste of Friend Daughters',
#   'Taste of Friend Daughters',
#   2018,
#   None,
#   'Adult,Drama,Romance'),
#  ('tt10071462',
#   'Bunker of Blood 07: Killjoys Carnage Caravan',
#   'Bunker of Blood 07: Killjoys Carnage Caravan',
#   2019,
#   88.0,
#   'Horror'),
#  ('tt10071696', 'Maa Purnagiri', 'Maa Purnagiri', 2019, 148.0, 'Family'),
#  ('tt10071700', 'DIO CÈ', 'DIO CÈ', 2019, None, 'Documentary'),
#  ('tt10071862',
#   'Mazlum Kuzey & Kuddusi 2 La! Kasada Para Var!',
#   'Mazlum Kuzey & Kuddusi 2 La! Kasada Para Var!',
#   2019,
#   None,
#   'Comedy'),
#  ('tt10071942',
#   'Kaun Mera Kaun Tera',
#   'Kaun Mera Kaun Tera',
#   2017,
#   None,
#   'Comedy'),
#  ('tt10071984', 'YSLA', 'YSLA', 2019, None, 'Musical'),
#  ('tt10072442',
#   'Rive-Sud Origine',
#   'Rive-Sud Origine',
#   2019,
#   70.0,
#   'Documentary,Mystery,Sci-Fi'),
#  ('tt10072948', 'Zhili-byli my', 'Zhili-byli my', 2017, 97.0, 'Family'),
#  ('tt10073008',
#   'The Shadow of Gold',
#   'The Shadow of Gold',
#   2019,
#   78.0,
#   'Documentary'),
#  ('tt10073018', 'The Game', 'The Game', 2019, None, 'Horror'),
#  ('tt10073132',
#   'Despedida de soltero',
#   'Despedida de soltero',
#   2013,
#   90.0,
#   'Thriller'),
#  ('tt10073438', 'Renegade', 'Renegade', 2019, None, 'Action'),
#  ('tt10073458',
#   'But What Was She Wearing?',
#   'But What Was She Wearing?',
#   2018,
#   110.0,
#   'Documentary'),
#  ('tt10073510',
#   'Once in a Hundred Years: The Life and Legacy of Marian Anderson',
#   'Once in a Hundred Years: The Life and Legacy of Marian Anderson',
#   2019,
#   None,
#   'Documentary'),
#  ('tt10073630', 'Kuvana', 'Kuvana', 2019, None, 'Drama'),
#  ...]

# %%
# Import movie_basics table using pandas
import pandas as pd

pd.DataFrame(
    data=cursor.execute("""SELECT * FROM movie_basics;""").fetchall(),
    columns=[x[0] for x in cursor.description]
)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
# Import movie_ratings table using pandas

pd.DataFrame(
    data=cursor.execute("""SELECT * FROM movie_ratings;""").fetchall(),
    columns=[x[0] for x in cursor.description]
)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Now that we have the connection, we can use the pd.read_sql method instead of using cursor
df = pd.read_sql("""SELECT * FROM movie_basics;""", conn)
df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
# Import directors table
pd.DataFrame(
    data=cursor.execute("""SELECT * FROM directors;""").fetchall(),
    columns=[x[0] for x in cursor.description]
)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %%
# This is the writers table. It's important because we'll dig about writers and their effect on movie ratings
pd.DataFrame(
    data=cursor.execute("""SELECT * FROM writers;""").fetchall(),
    columns=[x[0] for x in cursor.description]
)
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %%
# This is the persons table. It's important because we'll dig about actors and their effect on movie ratings
pd.DataFrame(
    data=cursor.execute("""SELECT * FROM persons;""").fetchall(),
    columns=[x[0] for x in cursor.description]
)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %%
# We're going to join all the data from the chosen tables(movie_basics, movie_ratings, directors, persons) to make it easier to handle to the data
#These are the columns we need; mb.movie_id, mb.primary_title, mb.genres, mb.start_year, mb.runtime_minutes, mr. averagerating, mr.numvotes, p.primary_name, p.primary_profession, d.person_id

q = """
SELECT mb.movie_id, mb.primary_title, mb.genres, mb.start_year, mb.runtime_minutes, mr. averagerating, mr.numvotes, p.primary_name, p.primary_profession, d.person_id
FROM movie_basics mb
JOIN movie_ratings mr
    ON mb.movie_id = mr.movie_id
JOIN directors d
    ON mb.movie_id = d.movie_id
JOIN persons p
    ON d.person_id = p.person_id
;
"""
df = pd.read_sql(q, conn)

# %%
# Show the first five rows to better understand the data

df.head()
# Out:
#     movie_id                    primary_title              genres  start_year  \
# 0  tt0063540                        Sunghursh  Action,Crime,Drama        2013
# 1  tt0063540                        Sunghursh  Action,Crime,Drama        2013
# 2  tt0063540                        Sunghursh  Action,Crime,Drama        2013
# 3  tt0063540                        Sunghursh  Action,Crime,Drama        2013
# 4  tt0066787  One Day Before the Rainy Season     Biography,Drama        2019
#
#    runtime_minutes  averagerating  numvotes         primary_name  \
# 0            175.0            7.0        77  Harnam Singh Rawail
# 1            175.0            7.0        77  Harnam Singh Rawail
# 2            175.0            7.0        77  Harnam Singh Rawail
# 3            175.0            7.0        77  Harnam Singh Rawail
# 4            114.0            7.2        43            Mani Kaul
#
#          primary_profession  person_id
# 0  director,writer,producer  nm0712540
# 1  director,writer,producer  nm0712540
# 2  director,writer,producer  nm0712540
# 3  director,writer,producer  nm0712540
# 4     director,writer,actor  nm0002411

# %% [markdown]
# 3.0 Previewing the Dataset

# %%
#checking the bottom of the dataset

df.tail()
# Out:
#          movie_id               primary_title       genres  start_year  \
# 181382  tt9914642                   Albatross  Documentary        2017
# 181383  tt9914642                   Albatross  Documentary        2017
# 181384  tt9914942  La vida sense la Sara Amat         None        2019
# 181385  tt9914942  La vida sense la Sara Amat         None        2019
# 181386  tt9916160                  Drømmeland  Documentary        2019
#
#         runtime_minutes  averagerating  numvotes        primary_name  \
# 181382              NaN            8.5         8        Chris Jordan
# 181383              NaN            8.5         8        Chris Jordan
# 181384              NaN            6.6         5           Laura Jou
# 181385              NaN            6.6         5           Laura Jou
# 181386             72.0            6.5        11  Joost van der Wiel
#
#                      primary_profession  person_id
# 181382           director,writer,editor  nm5300859
# 181383           director,writer,editor  nm5300859
# 181384   miscellaneous,actress,director  nm1716653
# 181385   miscellaneous,actress,director  nm1716653
# 181386  director,cinematographer,writer  nm5684093

# %%
#Show the data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181387 entries, 0 to 181386
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            181387 non-null  object
#  1   primary_title       181387 non-null  object
#  2   genres              180047 non-null  object
#  3   start_year          181387 non-null  int64
#  4   runtime_minutes     163584 non-null  float64
#  5   averagerating       181387 non-null  float64
#  6   numvotes            181387 non-null  int64
#  7   primary_name        181387 non-null  object
#  8   primary_profession  181262 non-null  object
#  9   person_id           181387 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 13.8+ MB

# %%
# Checking the number of entries in each column

df.count()
# Out:
# movie_id              181387
# primary_title         181387
# genres                180047
# start_year            181387
# runtime_minutes       163584
# averagerating         181387
# numvotes              181387
# primary_name          181387
# primary_profession    181262
# person_id             181387
# dtype: int64

# %%
# Generate summary statistics for numeric columns
df.describe()
# Out:
#           start_year  runtime_minutes  averagerating      numvotes
# count  181387.000000    163584.000000  181387.000000  1.813870e+05
# mean     2014.309802        97.789484       6.217683  4.955524e+03
# std         2.536111       194.434689       1.388026  3.760931e+04
# min      2010.000000         3.000000       1.000000  5.000000e+00
# 25%      2012.000000        84.000000       5.400000  1.900000e+01
# 50%      2014.000000        94.000000       6.300000  6.600000e+01
# 75%      2016.000000       107.000000       7.200000  3.110000e+02
# max      2019.000000     51420.000000      10.000000  1.841066e+06

# %% [markdown]
# 4.0 Cleaning the Dataset

# %% [markdown]
# 4.1 Checking Nulls

# %%
#Check the dataset for nulls

df.isnull().values.any()
# Out:
# True

# %%
# Let's get a summary of the missing data

df.isnull().sum()
# Out:
# movie_id                  0
# primary_title             0
# genres                 1340
# start_year                0
# runtime_minutes       17803
# averagerating             0
# numvotes                  0
# primary_name              0
# primary_profession      125
# person_id                 0
# dtype: int64

# %%
# Calculating the total number of null values

# Step 1: Calculate the total number of null values

null_count = df.isnull().sum()
null_count
# Out:
# movie_id                  0
# primary_title             0
# genres                 1340
# start_year                0
# runtime_minutes       17803
# averagerating             0
# numvotes                  0
# primary_name              0
# primary_profession      125
# person_id                 0
# dtype: int64

# %%
# Step 2: Calculate the total number of values (non-null)
total_count = df.shape[0]
total_count
# Out:
# 181387

# %%
# Step 3: Calculate the percentage od nulls for each column

null_percentage = (null_count / total_count) * 100
    
print(null_percentage)
# Out:
# movie_id              0.000000
# primary_title         0.000000
# genres                0.738752
# start_year            0.000000
# runtime_minutes       9.814926
# averagerating         0.000000
# numvotes              0.000000
# primary_name          0.000000
# primary_profession    0.068913
# person_id             0.000000
# dtype: float64

# %% [markdown]
# The above shows that there is a huge percantage of null values especially in the runtime_minutes column. The other columns have almost negligable nulls so we can do away with those.

# %%
# Remove null vales from studioand domestic_gross
df.dropna(subset = ['primary_profession'], inplace=True)
df.dropna(subset = ['genres'], inplace=True)

# %%
# Find the mode to relace the null values

runtime_minutes_mode = df['runtime_minutes'].mode()
runtime_minutes_mode
# Out:
# 0    90.0
# Name: runtime_minutes, dtype: float64

# %%
# Let's get a single mode value (the most frequent value)
# by using .iloc[0] to access the first mode in the Series
mode_value = runtime_minutes_mode.iloc[0]
mode_value
# Out:
# 90.0

# %%
#Replace the null values with mode

df['runtime_minutes'].fillna(mode_value, inplace=True)
df['runtime_minutes']
# Out:
# 0         175.0
# 1         175.0
# 2         175.0
# 3         175.0
# 4         114.0
#           ...
# 181380     98.0
# 181381     98.0
# 181382     90.0
# 181383     90.0
# 181386     72.0
# Name: runtime_minutes, Length: 179922, dtype: float64

# %%
# Recheck null values to confirm they're non existant

null_count = df.isnull().sum()
null_count
# Out:
# movie_id              0
# primary_title         0
# genres                0
# start_year            0
# runtime_minutes       0
# averagerating         0
# numvotes              0
# primary_name          0
# primary_profession    0
# person_id             0
# dtype: int64

# %%
# All the nulls are now gone.

# %% [markdown]
# 4.2 Checking Duplicates

# %%
#Check for duplicates

df.duplicated().value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         False
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 181380    False
# 181381     True
# 181382    False
# 181383     True
# 181386    False
# Length: 179922, dtype: bool>

# %%
# Let's drop the duplicate rows 
#We're going to start by checking out the duplicate rows to see what they look like. So let's check out the first 20 rows

#Identify duplicates
duplicates = df.duplicated(keep=False)  # keep=False marks all duplicates as True

# Filter and display the duplicate rows
duplicate_rows = df[duplicates]
duplicate_rows.head(20)
# Out:
#      movie_id                 primary_title                   genres  \
# 0   tt0063540                     Sunghursh       Action,Crime,Drama
# 1   tt0063540                     Sunghursh       Action,Crime,Drama
# 2   tt0063540                     Sunghursh       Action,Crime,Drama
# 3   tt0063540                     Sunghursh       Action,Crime,Drama
# 5   tt0069049    The Other Side of the Wind                    Drama
# 6   tt0069049    The Other Side of the Wind                    Drama
# 8   tt0100275      The Wandering Soap Opera     Comedy,Drama,Fantasy
# 9   tt0100275      The Wandering Soap Opera     Comedy,Drama,Fantasy
# 10  tt0100275      The Wandering Soap Opera     Comedy,Drama,Fantasy
# 11  tt0100275      The Wandering Soap Opera     Comedy,Drama,Fantasy
# 14  tt0146592                   Pál Adrienn                    Drama
# 15  tt0146592                   Pál Adrienn                    Drama
# 18  tt0162942  Children of the Green Dragon                    Drama
# 19  tt0162942  Children of the Green Dragon                    Drama
# 20  tt0162942  Children of the Green Dragon                    Drama
# 22  tt0176694            The Tragedy of Man  Animation,Drama,History
# 23  tt0176694            The Tragedy of Man  Animation,Drama,History
# 25  tt0230212             The Final Journey                    Drama
# 26  tt0230212             The Final Journey                    Drama
# 27  tt0230212             The Final Journey                    Drama
#
#     start_year  runtime_minutes  averagerating  numvotes         primary_name  \
# 0         2013            175.0            7.0        77  Harnam Singh Rawail
# 1         2013            175.0            7.0        77  Harnam Singh Rawail
# 2         2013            175.0            7.0        77  Harnam Singh Rawail
# 3         2013            175.0            7.0        77  Harnam Singh Rawail
# 5         2018            122.0            6.9      4517         Orson Welles
# 6         2018            122.0            6.9      4517         Orson Welles
# 8         2017             80.0            6.5       119           Raoul Ruiz
# 9         2017             80.0            6.5       119           Raoul Ruiz
# 10        2017             80.0            6.5       119    Valeria Sarmiento
# 11        2017             80.0            6.5       119    Valeria Sarmiento
# 14        2010            136.0            6.8       451         Ágnes Kocsis
# 15        2010            136.0            6.8       451         Ágnes Kocsis
# 18        2010             89.0            6.9       120      Bence Miklauzic
# 19        2010             89.0            6.9       120      Bence Miklauzic
# 20        2010             89.0            6.9       120      Bence Miklauzic
# 22        2011            160.0            7.8       584    Marcell Jankovics
# 23        2011            160.0            7.8       584    Marcell Jankovics
# 25        2010            120.0            8.8         8           R.J. Adams
# 26        2010            120.0            8.8         8           R.J. Adams
# 27        2010            120.0            8.8         8           R.J. Adams
#
#                       primary_profession  person_id
# 0               director,writer,producer  nm0712540
# 1               director,writer,producer  nm0712540
# 2               director,writer,producer  nm0712540
# 3               director,writer,producer  nm0712540
# 5                  actor,director,writer  nm0000080
# 6                  actor,director,writer  nm0000080
# 8               director,writer,producer  nm0749914
# 9               director,writer,producer  nm0749914
# 10                editor,director,writer  nm0765384
# 11                editor,director,writer  nm0765384
# 14              director,writer,producer  nm1030585
# 15              director,writer,producer  nm1030585
# 18    director,writer,assistant_director  nm1207262
# 19    director,writer,assistant_director  nm1207262
# 20    director,writer,assistant_director  nm1207262
# 22  writer,director,animation_department  nm0417757
# 23  writer,director,animation_department  nm0417757
# 25                 actor,writer,director  nm0011276
# 26                 actor,writer,director  nm0011276
# 27                 actor,writer,director  nm0011276

# %%
# Remove all duplicates based on the 'movie_id' and 'primary_title' columns

df_no_duplicates = df.drop_duplicates(subset=['movie_id', 'primary_title'], keep='first')
df_no_duplicates
# Out:
#          movie_id                    primary_title                genres  \
# 0       tt0063540                        Sunghursh    Action,Crime,Drama
# 4       tt0066787  One Day Before the Rainy Season       Biography,Drama
# 5       tt0069049       The Other Side of the Wind                 Drama
# 7       tt0069204                  Sabse Bada Sukh          Comedy,Drama
# 8       tt0100275         The Wandering Soap Opera  Comedy,Drama,Fantasy
# ...           ...                              ...                   ...
# 181377  tt9913056                     Swarm Season           Documentary
# 181378  tt9913084                 Diabolik sono io           Documentary
# 181380  tt9914286                Sokagin Çocuklari          Drama,Family
# 181382  tt9914642                        Albatross           Documentary
# 181386  tt9916160                       Drømmeland           Documentary
#
#         start_year  runtime_minutes  averagerating  numvotes  \
# 0             2013            175.0            7.0        77
# 4             2019            114.0            7.2        43
# 5             2018            122.0            6.9      4517
# 7             2018             90.0            6.1        13
# 8             2017             80.0            6.5       119
# ...            ...              ...            ...       ...
# 181377        2019             86.0            6.2         5
# 181378        2019             75.0            6.2         6
# 181380        2019             98.0            8.7       136
# 181382        2017             90.0            8.5         8
# 181386        2019             72.0            6.5        11
#
#                 primary_name               primary_profession  person_id
# 0        Harnam Singh Rawail         director,writer,producer  nm0712540
# 4                  Mani Kaul            director,writer,actor  nm0002411
# 5               Orson Welles            actor,director,writer  nm0000080
# 7       Hrishikesh Mukherjee           director,editor,writer  nm0611531
# 8                 Raoul Ruiz         director,writer,producer  nm0749914
# ...                      ...                              ...        ...
# 181377       Sarah Christman    miscellaneous,director,editor  nm1502645
# 181378       Giancarlo Soldi         director,writer,producer  nm0812850
# 181380     Ahmet Faik Akinci                  director,writer  nm4394529
# 181382          Chris Jordan           director,writer,editor  nm5300859
# 181386    Joost van der Wiel  director,cinematographer,writer  nm5684093
#
# [72382 rows x 10 columns]

# %% [markdown]
# 4.3 Checking for data inconsistencies

# %%
df.describe()
# Out:
#           start_year  runtime_minutes  averagerating      numvotes
# count  179922.000000    179922.000000  179922.000000  1.799220e+05
# mean     2014.310546        97.096231       6.213478  4.995573e+03
# std         2.532863       185.397821       1.386565  3.775948e+04
# min      2010.000000         3.000000       1.000000  5.000000e+00
# 25%      2012.000000        85.000000       5.400000  2.000000e+01
# 50%      2014.000000        91.000000       6.300000  6.600000e+01
# 75%      2016.000000       105.000000       7.200000  3.160000e+02
# max      2019.000000     51420.000000      10.000000  1.841066e+06

# %% [markdown]
# 'domestic_gross' Column:
#
# The minimum value is 100 (min: 1.000000e+02), which suggests there are some very low domestic gross values. This is not really an inconsistency.
#
# The 'year' column's minimum value is 2010 (min: 2010.000000), and the maximum value is 2018 (max: 2018.000000). These values fall within a reasonable range for movie release years.

# %% [markdown]
# 4.4 Checking the data types

# %%
#df.info() is useful for understanding the structure of your DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179922 entries, 0 to 181386
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            179922 non-null  object
#  1   primary_title       179922 non-null  object
#  2   genres              179922 non-null  object
#  3   start_year          179922 non-null  int64
#  4   runtime_minutes     179922 non-null  float64
#  5   averagerating       179922 non-null  float64
#  6   numvotes            179922 non-null  int64
#  7   primary_name        179922 non-null  object
#  8   primary_profession  179922 non-null  object
#  9   person_id           179922 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 15.1+ MB

# %% [markdown]
# 5.0 Exploratory Data Analysis(EDA)

# %% [markdown]
# Univariate Analysis
#
# Univariate analysis is a statistical method used to analyze and summarize data involving a single variable. In univariate analysis, you focus on understanding the characteristics, patterns, and distributions of one variable at a time, without considering the relationships or dependencies between variables. It helps you gain insights into the distribution, central tendency, and variability of a single variable.

# %%
df.head(10)
# Out:
#     movie_id                    primary_title                genres  \
# 0  tt0063540                        Sunghursh    Action,Crime,Drama
# 1  tt0063540                        Sunghursh    Action,Crime,Drama
# 2  tt0063540                        Sunghursh    Action,Crime,Drama
# 3  tt0063540                        Sunghursh    Action,Crime,Drama
# 4  tt0066787  One Day Before the Rainy Season       Biography,Drama
# 5  tt0069049       The Other Side of the Wind                 Drama
# 6  tt0069049       The Other Side of the Wind                 Drama
# 7  tt0069204                  Sabse Bada Sukh          Comedy,Drama
# 8  tt0100275         The Wandering Soap Opera  Comedy,Drama,Fantasy
# 9  tt0100275         The Wandering Soap Opera  Comedy,Drama,Fantasy
#
#    start_year  runtime_minutes  averagerating  numvotes          primary_name  \
# 0        2013            175.0            7.0        77   Harnam Singh Rawail
# 1        2013            175.0            7.0        77   Harnam Singh Rawail
# 2        2013            175.0            7.0        77   Harnam Singh Rawail
# 3        2013            175.0            7.0        77   Harnam Singh Rawail
# 4        2019            114.0            7.2        43             Mani Kaul
# 5        2018            122.0            6.9      4517          Orson Welles
# 6        2018            122.0            6.9      4517          Orson Welles
# 7        2018             90.0            6.1        13  Hrishikesh Mukherjee
# 8        2017             80.0            6.5       119            Raoul Ruiz
# 9        2017             80.0            6.5       119            Raoul Ruiz
#
#          primary_profession  person_id
# 0  director,writer,producer  nm0712540
# 1  director,writer,producer  nm0712540
# 2  director,writer,producer  nm0712540
# 3  director,writer,producer  nm0712540
# 4     director,writer,actor  nm0002411
# 5     actor,director,writer  nm0000080
# 6     actor,director,writer  nm0000080
# 7    director,editor,writer  nm0611531
# 8  director,writer,producer  nm0749914
# 9  director,writer,producer  nm0749914

# %% [markdown]
# Objectives
# 5.1 To identify the most frequently occurring movie ID
# 5.2 To create insight on the types of films that perform well in terms of numvotes
# 5.3 To create insight on audience reception on different types of movies
# 5.4 To create insight on which directors have highest numvotes and average ratings
# 5.5 To provide any other actionable insights to guide Microsoft on which films to create

# %%
# Let's start by calculating the number of unique movie IDs to understand the number of unique movies in your dataset. 

unique_movie_ids = df['movie_id'].nunique()
unique_movie_ids
# Out:
# 72382

# %% [markdown]
# 5.1 Let's identify the types of films that perform well in terms of numvotes,
# let's start by analyzing the genres and averagerating columns in the dataset.

# %%
genre_ratings = df.groupby('genres')['numvotes'].mean().sort_values(ascending=False)
genre_ratings.head(10)
# Out:
# genres
# Action,Adventure,Sci-Fi      281551.713615
# Adventure,Mystery,Sci-Fi     215778.000000
# Action,Adventure,Fantasy     143266.062315
# Adventure,Fantasy            120143.217391
# Drama,History,Musical        110238.230769
# Adventure,Drama,Western      106879.000000
# Action,Adventure,Thriller    105231.680000
# Family,Fantasy,Musical        99321.083333
# Action,Crime,Sci-Fi           94424.000000
# Action,Adventure,Mystery      92483.468750
# Name: numvotes, dtype: float64

# %%
# Identify the genres with the highest average ratings. These are the genres that, on average, perform well in terms of ratings.

top_rated_genres = genre_ratings.head(10)
top_rated_genres
# Out:
# genres
# Action,Adventure,Sci-Fi      281551.713615
# Adventure,Mystery,Sci-Fi     215778.000000
# Action,Adventure,Fantasy     143266.062315
# Adventure,Fantasy            120143.217391
# Drama,History,Musical        110238.230769
# Adventure,Drama,Western      106879.000000
# Action,Adventure,Thriller    105231.680000
# Family,Fantasy,Musical        99321.083333
# Action,Crime,Sci-Fi           94424.000000
# Action,Adventure,Mystery      92483.468750
# Name: numvotes, dtype: float64

# %%
# Visualize the data

import pandas as pd
import matplotlib.pyplot as plt

# Calculate the average rating for each genre

genre_ratings = df.groupby('genres')['averagerating'].mean().sort_values(ascending=False)

# Select the top-rated genres 

top_rated_genres = genre_ratings.head(20)

# Create a bar chart to visualize the top-rated genres
plt.figure(figsize=(11, 6))
top_rated_genres.plot(kind='bar')
plt.title('Top-Rated Genres')
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
5.2 Create insight on audience reception on different types of movies
# Out:
#   Cell In[37], line 1
#     5.2 Create insight on audience reception on different types of movies
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Creating insights into audience reception for different types of movies involves analyzing and visualizing data to understand how different genres or movie attributes relate to audience ratings. Here's a step-by-step approach to gaining insights:
#
# Group by Genres:
#
# Group your dataset by the genres column.

# %%
genre_group = df.groupby('genres')
genre_group

# %% [markdown]
# Calculate Summary Statistics:
#
# Calculate key summary statistics for each genre, such as the mean, median, and count of ratings. These statistics will provide an overview of how each genre is rated.

# %%
genre_stats = genre_group['averagerating'].agg(['mean', 'median', 'count']).sort_values(by='mean', ascending=False)
genre_stats.head(20)

# %% [markdown]
# Visualize Genre Ratings:
#
# Create visualizations to better understand how genres perform in terms of audience ratings. Here are some visualization ideas:
# a. Bar Chart for Mean Ratings:
#
# Create a bar chart to display the mean ratings for each genre, sorted by highest mean rating.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
genre_stats[['mean']].plot(kind='bar', legend=False)
plt.title('Mean Ratings by Genre')
plt.xlabel('Genres')
plt.ylabel('Mean Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# b. Box Plot for Rating Distribution:
#
# Create box plots to visualize the distribution of ratings within each genre. This can help you understand the spread of ratings and identify outliers.
# python

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='genres', y='averagerating', data=df)
plt.title('Rating Distribution by Genre')
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
5.3 To create insight on which directors have highest numvotes and average ratings

# %%
# Group by Director:

# Group your dataset by the primary_name column, which represents the directors.

director_group = df.groupby('primary_name')
director_group

# %% [markdown]
# Calculate Summary Statistics:

# %%
# Calculate key summary statistics for each director, such as the sum of numvotes and the mean of averagerating. 
# These statistics will provide an overview of how each director's movies are rated 
# and how many votes their movies have received.

director_stats = director_group[['numvotes', 'averagerating']].agg({'numvotes': 'sum', 'averagerating': 'mean'}).reset_index()
director_stats.head(10)

# %% [markdown]
# So these show how each director's movies are rated and how many votes their movies have received.

# %%
# Sort the resulting DataFrame by the sum of numvotes in descending order 
# to find the directors with the highest number of votes.

top_directors_by_votes = director_stats.sort_values(by='numvotes', ascending=False)
top_directors_by_votes.head(30)

# %%
Sort by Average Rating:

# %%
# Sort the DataFrame by the mean of averagerating in descending order to find the directors with the highest average ratings.

top_directors_by_rating = director_stats.sort_values(by='averagerating', ascending=False)
top_directors_by_rating.head(30)

# %%
Visualize the Data:

# %%
# Create visualizations, such as bar charts, to display the top directors with the highest number of votes and the highest average ratings.

import matplotlib.pyplot as plt

# Bar chart for top directors by number of votes
plt.figure(figsize=(12, 6))
plt.bar(top_directors_by_votes['primary_name'].head(10), top_directors_by_votes['numvotes'].head(10))
plt.title('Top Directors by Number of Votes')
plt.xlabel('Directors')
plt.ylabel('Total Votes')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for top directors by average rating

plt.figure(figsize=(12, 6))
plt.bar(top_directors_by_rating['primary_name'].head(20), top_directors_by_rating['averagerating'].head(20))
plt.title('Top Directors by Average Rating')
plt.xlabel('Directors')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# These steps will help identify the directors who have received the highest number of votes
# and have the highest average ratings for their movies.

# %% [markdown]
# Summart results.

# %% [markdown]
# 5.2 Based on insight on audience reception on different types of movies
#
# Here's a summary of the key statistics for the top 10 genres based on mean ratings:
#
# 1. Comedy, Documentary, Fantasy: This genre received the highest mean rating of 9.4, indicating exceptionally positive audience feedback. However, please note that there's only one rating available for this genre.
# 2. History, Sport: With a mean rating of 9.2, this genre also received very high ratings. It is another genre with a limited number of ratings
# 3. Game-Show: Game-Show genre has a mean rating of 9.0, which suggests strong audience appreciation. There are a total of 6 ratings for this genre.
# 4. Music, Mystery: This genre also has a mean rating of 9.0, indicating high viewer satisfaction, with 3 ratings recorded.
# 5. Documentary, News, Sport: With an 8.8 mean rating, this genre is well-received, but it has a relatively small sample size of 2 ratings.
# 6. Documentary, News, Reality-TV: Similar to the previous genre, it also has an 8.8 mean rating, based on 3 ratings.
# 7. Comedy, Drama, Reality-TV: This genre achieved an 8.8 mean rating and, like the previous two, has a limited number of ratings
# 8. Drama, Short: With an 8.8 mean rating, this genre also received positive feedback. However, there's only 1 rating for this genre.
# 9. Drama, Fantasy, War: This genre received an 8.8 mean rating, based on 2 ratings.
# 10. Documentary, Family, News: This genre has a mean rating of 8.7, indicating strong viewer satisfaction. Notably, it has a larger sample size of 106 ratings.

# %% [markdown]
# 5.3 Here's a summary of the key statistics for the top 10 directors based on the sum of numvotes and the mean of averagerating:
#
# 1.A Normale Jef: Movies directed by A Normale Jef have received a total of 1426 votes, with an average rating of 7.2.
#
# 2. A'Ali de Sousa: This director's movies have received 55 votes on average, with a mean rating of 4.2.
#
# 3. A. Blaine Miller: A. Blaine Miller's movies have received 8 votes in total, with an average rating of 7.0.
#
# 4. A. Cengiz Mert: The director A. Cengiz Mert's movies have received a total of 6 votes, and they have an average rating of 3.2.
#
# 5. A. Fishman: Movies directed by A. Fishman have received 37 votes on average, with an impressive average rating of 7.8.
#
# 6. A. Haluk Unal: This director's movies have received an average of 5 votes, and they have an excellent mean rating of 8.8.
#
# 7. A. Jagadesh: A. Jagadesh's movies have received a total of 291 votes, with an average rating of 3.5.
#
# 8. A. Joji: Movies directed by A. Joji have received 6 votes on average, with a mean rating of 5.5.
#
# 9. A. Karunakaran: A. Karunakaran's movies have received a substantial total of 4676 votes, and they have an average rating of 5.8125.
#
# 10. A. Lawrence Dreyfuss: Movies directed by A. Lawrence Dreyfuss have received 17 votes on average, with a mean rating of 7.0.
#
# These statistics provide insights into how each director's movies are rated and the level of audience engagement, as measured by the total number of votes received. Directors with higher mean ratings and larger sums of numvotes may be considered more successful or influential in the industry.

# %% [markdown]
# 5.4 Here’s the overall best directors based on highest average ratings (9 out of 10 directors got a perfect score on the average ratings.)
#
#
# 1. Michiel Brongers: Michiel Brongers has an impressive average rating of 10.0 based on 5 votes.
#
# 2. Masahiro Hayakawa: Masahiro Hayakawa also has a perfect average rating of 10.0 with 5 votes.
#
# 3. Emre Oran: Emre Oran maintains a perfect 10.0 average rating with 6 votes.
#
# 4. Lindsay Thompson: Lindsay Thompson's movies have an average rating of 10.0, based on 7 votes.
#
# 5. Ivana Diniz: Ivana Diniz's movies have an excellent average rating of 10.0, backed by 10 votes.
#
# 6. Tristan David Luciotti: Tristan David Luciotti's films have a 10.0 average rating with 6 votes.
#
# 7. Chad Carpenter: Chad Carpenter has a perfect average rating of 10.0 with 5 votes.
#
# 8. Stephen Peek: Stephen Peek's movies have an average rating of 10.0, supported by 20 votes.
#
# 9. Loreto Di Cesare: Loreto Di Cesare's films also maintain a perfect 10.0 average rating with 16 votes.
#
# 10. Kalyan Varma: Kalyan Varma's movies have a high average rating of 9.9 with 10 votes.
#
# These directors have received exceptionally high average ratings for their work, suggesting that their movies are highly regarded by audiences.

# %% [markdown]
# Recommendations
#
# Based on the results obtained from the project, which include genre statistics, director statistics, and top directors by average ratings, we can draw several conclusions and make recommendations:
#
#
# 1. Genre Statistics (5.2):
#
# The analysis of genre statistics has revealed that certain genres have exceptionally high mean ratings, indicating strong audience reception.
# However, it's crucial to consider that genres with extremely high ratings often have limited data, which means these ratings may not be representative of broader trends.
# Recommendations: For Microsoft's entry into the movie industry, it's advisable to explore genres that consistently perform well and have a substantial sample size for more reliable insights.
# 2. Director Statistics (5.3):
#
# The director statistics provide valuable insights into how each director's movies are rated and the number of votes they have received.
# Several directors stand out with exceptionally high average ratings, although some have relatively small sample sizes.
# Recommendations: Collaborating with directors who consistently produce highly rated films could be a strategic move for Microsoft's movie studio. However, it's essential to consider the director's track record in terms of both ratings and the number of votes to assess their broader appeal.
# 3. Top Directors by Average Ratings (5.4):
#
# The list of directors with the highest average ratings showcases filmmakers who have achieved perfect ratings (10.0) with a limited number of votes.
# While these directors demonstrate exceptional quality, the small sample sizes may not represent widespread audience sentiment.
# Recommendations: Microsoft could explore partnerships with top-rated directors for niche or specialized projects, but it's crucial to balance high ratings with audience reach. Collaborations should be based on a comprehensive evaluation of both factors.
# Project Limitations:
#
# The project's conclusions are based on available data, and the quality of the insights depends on the dataset's completeness and representativeness.
# Some genres or directors may not have sufficient data, limiting the depth of analysis.
# The analysis does not account for temporal trends or changing audience preferences, which could impact future performance.
# Future Improvement Ideas:
#
# - Continuously update and expand the dataset to include more recent movies and ratings.
# - Consider sentiment analysis to understand audience sentiments and preferences in-depth.
# - Explore factors beyond genres and directors, such as cast, budget, and marketing, to gain a comprehensive view of movie success.
# - Develop predictive models to forecast the potential success of future movies based on various factors.
# - Conduct market research to understand the competitive landscape and audience demands in the movie industry.
#
# In summary, while the analysis provides valuable insights, it's important to approach decision-making in the movie industry with a comprehensive understanding of various factors, including audience trends and market dynamics. Collaboration with highly-rated directors and exploration of popular genres should be part of a broader strategy for Microsoft's entry into the movie industry.
